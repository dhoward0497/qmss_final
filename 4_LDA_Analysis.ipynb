# %%
from ast import literal_eval
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel, ldamodel, LdaMulticore
from gensim.parsing.preprocessing import STOPWORDS
from gensim.test.utils import common_corpus, common_texts, common_dictionary
from gensim.utils import simple_preprocess
from nltk import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from statistics import mean
import gensim
import nltk
import numpy as np
import os
import pandas as pd
import random
import warnings
warnings.filterwarnings("ignore")

# %%
stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

# %%
overview = pd.read_csv("debate_data/data_overviews/overview_1.csv")

def string_2_row(df_w_col_name):
    count = 0
    for row in df_w_col_name:
        df_w_col_name[count] = literal_eval(row)
        count+=1
        
string_2_row(overview["moderator"])
string_2_row(overview["participants"])

# %%
# create stop_words list to be removed when LDA analysis is being conducted

nltk_stop = list(set(stopwords.words('english')))

political_stop_words = ["president", "american", "america", "govern", "government", "campaign",\
                        "country","applause","question","governor", "congresswoman", "congress",\
                       "congressman", "partisan", "republican", "democrat", "DNC","GOP","liberal",\
                       "conservative", "senate", "state", "left","right", "nomination","parti","party",
                       "democraci","constitut","politician","political","politics","pols","politi","federal",\
                       "feder", "polici","state","minister","govern","caucus","primary"]
                       
other_stop_words = ["think", "thank", "you","would", "peopl","work","reform", "family", "administr",\
                    "program","thing","peopl", "support","person","progress",\
                    "nominate""nomination","court","argument","process","man","men","woman","women", "legisl",\
                   "languag", "respect","report", "place", "today","title","issu","issue","titl", "year",\
                   "system", "record","world","laughter","laugh","farmer","earmark","office","offic",
                   "power","church", "someth", "reason", "promise", "promis", "tonight","everybodi","formosa",
                   "someon", "creat", "simpl", "percent", "faith", "mean", "need", "pocket" "percent", \
                    "secretari", "point", "noth", "ground", "build", "public", "middl", "mean", "centuri",\
                    "minut", "becom", "answer", "matter", "folk", "cours", "mean", "order" , "percent",\
                    "term", "posit", "communiti", "health", "mandat", "children", "public", "speech", \
                    "nomine", "differ", "month", "point", "everyon", "stand","everi","believ", "opportun",\
                   "understand","bring","choice", "histori", "servic", "background", "check", "nation", \
                    "littl", "friend", "critic","inequ", "realli", "somebodi", "problem", "share", "challeng", \
                    "togeth", "street", "start", "continu", "improv", "trust", "provid", "decis"]

names = ["michael", "donald", "chris", 'hillary', 'david', 'martha', 'hillari' ,"chang","barack","putin","jeb"]

for mods in overview["moderator"]:
    try:
        for mod in mods:
            names.append(mod)
    except:
        pass

for parts in overview["participants"]:
    try:
        for part in parts:
            names.append(part[:-4])
    except:
        pass

for title in overview["debate_name"]:
    t = title.replace("-"," ").split(" ")
    for z in t:
        names.append(str(z))

names = list(set(names))


states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', \
          'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', \
          'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Montana', 'Nebraska', 'Nevada', \
          'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', \
          'Oklahoma', 'Oregon', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri',\
          'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 
          'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

splitted_states = []
for s in states:
    for x in s.split(" "):
        splitted_states.append(x)
splitted_states = list(set(splitted_states))

stop_words = list(set(nltk_stop + political_stop_words + other_stop_words + names + splitted_states))

stop_words = [lemmatizer.lemmatize(t) for t in stop_words]
stop_words = [stemmer.stem(t) for t in stop_words]
stop_words = [t.lower() for t in stop_words]

stop_words = list(set(stop_words))

# %%
# function below finds the best params for the LDA model

def best_params(filename):
    
    try:
        df = pd.read_csv(directory+"/"+filename)
    except:
        df = filename
        
    processed_docs = []
    
    for row in df["speech"]:
        sentence = []
        for word in row.split(" "):
            x = re.sub('[^a-zA-Z]+', '', word)
            if len(x) > 4:
                if str(nltk.pos_tag([x])[0][1])[0] in ["N","J"]:
                    if x not in stop_words:
                        sentence.append(x)
        processed_docs.append(sentence)
        
    flat_list = []
    for sublist in processed_docs:
        for item in sublist:
            flat_list.append(item)

    vectorizer = TfidfVectorizer(analyzer='word', min_df=10, stop_words='english', lowercase=True,\
                                 token_pattern='[a-zA-Z0-9]{4,}')
    data_vectorized = vectorizer.fit_transform(flat_list)
    
    # Define Search Param
    search_params = {'n_components': [8,10,12,14,15],
                     'learning_decay': [0.6, 0.7, 0.8, 0.9]}

    # Initiate the Model
    lda = LatentDirichletAllocation()

    # Init Grid Search Class
    model = GridSearchCV(lda, param_grid = search_params)

    # Do the Grid Search
    model.fit(data_vectorized)
    
    try:
        best_lda_model = model.best_estimator_
        print("Best Model's Params: ", model.best_params_)
        print("Best Log Likelihood Score: ", model.best_score_)
    except:
        pass

    return (filename, model.best_params_)

# %%
# total topics

all_speech = []
directory = "debate_data/debates_part"
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        df = pd.read_csv(directory+"/"+filename)
        for row in df["speech"]:
            all_speech.append(row)

            
df = pd.DataFrame(all_speech, columns = ["speech"])         
            
x = best_params(df)

# %%
# best params for debates

samples = []

while(list(set(samples))) < ((0.25)*(len(overview["coder"]))):
    samples.append(overview["coder"][random.randint(0, len(overview["coder"]))])    

print(samples)
    
directory = "debate_data/debates_part"

best_param_results = []
counter = 1
for filename in os.listdir(directory):
    
    if filename.endswith(".csv"):
        
        coder = str(filename.split(".")[0])
        
        if coder in samples:

            print("number ", counter, ":", coder)
            counter+=1
            x = best_params(filename)
            best_param_results.append(x)
            
print("RESULTS FOR DEBATE TOPICS\n")
ds = []
for i in range(len(best_param_results)):
    ds.append(best_param_results[i][1])

d = {}
for i in ds:
    for k in i.keys():
        d[k] = tuple(d[k] for d in ds)

for st,vals in d.items():
    print("Average value for {} is {}".format(st,mean(vals)))
    try:
        print("Std for {} is {}".format(st,np.std(vals)))
    except:
        pass

# %%
directory = "debate_data/debates_part"

for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        df = pd.read_csv(directory+"/"+filename)
        coder = str(filename.split(".")[0])

        try:

            processed_docs = []

            for row in df["speech"]:

                sentence = []
                for word in row.split(" "):
                    x = re.sub('[^a-zA-Z]+', '', word)
                    if len(x) > 4:
                        if str(nltk.pos_tag([x])[0][1])[0] in ["N","J"]:
                            if x not in stop_words:
                                sentence.append(x)
                processed_docs.append(sentence)

            dictionary = gensim.corpora.Dictionary(processed_docs)
            dictionary.filter_extremes(no_above = 0.75)
            bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

            lda_model = LdaMulticore(bow_corpus,
                      num_topics = 4,
                      id2word = dictionary,
                      workers = 3,
                      passes = 15,
                      decay = 0.77,
                      minimum_probability = 0.0)        

            top_topics = lda_model.get_document_topics(bow_corpus, minimum_probability=0.0)

            topic_n = []
            topic_share = []
            for i in range(4):
                topic_n.append(i)
                count = 0
                n = 0
                for x in top_topics:
                    count += x[i][1]
                    n += 1
                avg = count / n
                topic_share.append(avg)

            sum_terms = []
            topic_terms = []

            for i in lda_model.print_topics(num_words = 8):
                words = []
                value = 0
                out_list = i[1].split("+")
                for x in out_list:
                    num = literal_eval(x.split("*")[0][1:])
                    value+=num

                sum_terms.append(value)

                for x in out_list:
                    t = x.replace('"', " ").strip(" ").split("*")[1]
                    words.append(t.strip(" "))
                stringed = ', '.join(words)
                topic_terms.append([stringed])

            df = pd.DataFrame(list(zip(topic_share, topic_terms, sum_terms)),
                              columns = ["topic_share", "topic_terms","sum_terms"]) 

            print(coder, "\n", df ,"\n")
            
            ###SAVE LDA MODEL UNIQUE FOR EACH DEBATE
            
        except:
            print("\n********", coder, " failed to be modelled \n")
# Out:
# D2000jan08
#     topic_share                                        topic_terms  sum_terms
# 0     0.390899  [medicar, import, secur, insur, protect, medic...      0.734
# 1     0.214880  [fight, second, futur, leadership, special, in...      0.818
# 2     0.256049  [school, teacher, propos, class, number, learn...      0.770
# 3     0.138170  [agricultur, access, money, futur, import, int...      0.817
#
# G1988oct05
#     topic_share                                        topic_terms  sum_terms
# 0     0.195656  [trade, market, foreign, tough, dollar, intere...      0.803
# 1     0.245706  [georg, commit, interest, futur, econom, major...      0.751
# 2     0.191602  [lloyd, futur, leadership, dollar, protect, ex...      0.716
# 3     0.367034  [secur, situat, defens, deficit, qualif, budge...      0.614
#
# R2007sep27
#     topic_share                                        topic_terms  sum_terms
# 0     0.217552  [individu, respons, militari, justic, equal, m...      0.710
# 1     0.254683  [import, school, welfar, money, moral, employ,...      0.682
# 2     0.256320  [illeg, penalti, border, death, secur, immigr,...      0.754
# 3     0.271445  [prison, troop, suggest, involv, african, seco...      0.556
#
# R2015sep16
#     topic_share                                        topic_terms  sum_terms
# 0     0.251433  [parenthood, immigr, money, amend, legal, figh...      0.254
# 1     0.255061  [militari, nuclear, elect, chief, ronald, weap...      0.249
# 2     0.268098  [marijuana, strong, justic, medic, money, deci...      0.257
# 3     0.225394  [leadership, radic, syria, clear, illeg, requi...      0.219
#
# R2011jun13
#     topic_share                                        topic_terms  sum_terms
# 0     0.212807  [obamacar, repeal, organ, spend, second, direc...      0.546
# 1     0.247687  [economi, privat, sector, wrong, futur, money,...      0.641
# 2     0.221500  [propos, medicar, market, price, money, actual...      0.576
# 3     0.318018  [secur, learn, command, money, import, protect...      0.515
#
# G2008oct07
#     topic_share                                        topic_terms  sum_terms
# 0     0.322835  [energi, spend, import, situat, budget, laden,...      0.406
# 1     0.102652  [stabil, market, money, compani, afford, propo...      0.567
# 2     0.303536  [nuclear, economi, interest, secur, import, sp...      0.422
# 3     0.270915  [insur, small, respons, fundament, credit, rus...      0.516
#
# R2011sep22
#     topic_share                                        topic_terms  sum_terms
# 0     0.232408  [school, parent, local, control, level, depart...      0.624
# 1     0.203094  [illeg, border, immigr, address, actual, liber...      0.689
# 2     0.204419  [secur, social, obamacar, number, dollar, wron...      0.758
# 3     0.360078  [economi, money, clear, second, corpor, capit,...      0.425
#
# D2007nov15
#     topic_share                                        topic_terms  sum_terms
# 0     0.213098  [secur, immigr, worker, illeg, legal, driver, ...      0.475
# 1     0.327933  [school, number, cheer, import, troop, class, ...      0.519
# 2     0.175059  [energi, nuclear, corpor, strong, experi, inte...      0.570
# 3     0.283915  [trade, china, elect, worker, respons, pakista...      0.469
#
# D2004jan29
#     topic_share                                        topic_terms  sum_terms
# 0     0.261023  [georg, elect, result, militari, protect, inte...      0.944
# 1     0.274042  [insur, benefit, militari, leadership, whole, ...      0.920
# 2     0.228922  [secur, import, protect, elect, leadership, in...      0.925
# 3     0.236004  [actual, worker, independ, whole, intellig, im...      0.928
#
# R2016feb06
#     topic_share                                        topic_terms  sum_terms
# 0     0.284213  [import, group, elect, enforc, terrorist, exam...      0.336
# 1     0.215655  [veteran, militari, second, execut, focus, reb...      0.520
# 2     0.254948  [korea, border, domain, missil, command, budge...      0.429
# 3     0.245185  [money, tremend, marco, fight, obamacar, accou...      0.365
#
#
# ******** D2016jan25  failed to be modelled
#
# D2016apr14
#     topic_share                                        topic_terms  sum_terms
# 0     0.259402  [israel, palestinian, money, interest, cours, ...      0.512
# 1     0.226323  [secur, social, effort, minimum, begin, absolu...      0.561
# 2     0.238650  [import, weapon, fossil, second, manufactur, r...      0.463
# 3     0.275555  [decis, actual, economi, attack, worker, break...      0.467
#
# R1999oct28
#     topic_share                                        topic_terms  sum_terms
# 0     0.204680  [incom, money, dollar, import, basic, liberti,...      0.952
# 1     0.236289  [money, dollar, basic, young, interest, financ...      0.955
# 2     0.297544  [school, import, liberti, found, young, money,...      0.963
# 3     0.261498  [special, interest, insur, financ, young, foun...      0.970
#
# R2016feb13
#     topic_share                                        topic_terms  sum_terms
# 0     0.210338  [attack, situat, clear, elect, leadership, wat...      0.565
# 1     0.309769  [justic, suprem, scalia, elect, second, econom...      0.562
# 2     0.220686  [secur, command, chief, economi, militari, lis...      0.577
# 3     0.259198  [immigr, money, illeg, listen, legal, fight, o...      0.530
#
# G1988oct13
#     topic_share                                        topic_terms  sum_terms
# 0     0.278453  [secur, spend, social, clean, deficit, sound, ...      0.556
# 1     0.318122  [decis, defens, convent, soviet, weapon, budge...      0.448
# 2     0.134207  [strong, weapon, deterr, proud, sound, exampl,...      0.526
# 3     0.269221  [georg, young, futur, elect, secur, heard, pos...      0.569
#
# R2000feb15
#     topic_share                                        topic_terms  sum_terms
# 0     0.254132  [militari, moral, general, import, death, clea...      0.566
# 1     0.249295  [interest, secur, spend, daughter, strateg, mo...      0.538
# 2     0.237358  [commit, experi, crime, elect, result, speak, ...      0.534
# 3     0.259249  [money, heart, messag, access, racial, interne...      0.558
#
# G2008oct02
#     topic_share                                        topic_terms  sum_terms
# 0     0.271360  [class, economi, econom, commit, anyth, credit...      0.469
# 1     0.219286  [israel, regul, increas, militari, troop, geor...      0.494
# 2     0.248326  [energi, break, independ, import, fight, produ...      0.517
# 3     0.261017  [afghanistan, nuclear, troop, leader, money, n...      0.580
#
# G2016sep26
#     topic_share                                        topic_terms  sum_terms
# 0     0.173733  [worst, african, invest, economi, beauti, trou...      0.559
# 1     0.298628  [compani, money, young, watch, learn, china, c...      0.519
# 2     0.222265  [negoti, includ, import, everyth, certain, tra...      0.597
# 3     0.293163  [trade, economi, money, wealthi, actual, numbe...      0.488
#
# G1980sep21
#     topic_share                                        topic_terms  sum_terms
# 0     0.361338  [money, addit, reduc, industri, propos, inflat...      0.695
# 1     0.306971  [figur, militari, individu, suppli, spend, inc...      0.756
# 2     0.253069  [simpli, begin, increas, possibl, import, pric...      0.650
# 3     0.078617  [import, individu, specif, addit, increas, pro...      0.622
#
# D2016mar06
#     topic_share                                        topic_terms  sum_terms
# 0     0.236599  [water, money, dollar, begin, prioriti, infras...      0.687
# 1     0.306461  [crimin, justic, import, everyth, investig, yo...      0.601
# 2     0.165782  [school, number, prioriti, clear, infrastructu...      0.574
# 3     0.291170  [corpor, trade, industri, dollar, second, disa...      0.530
#
# D2000mar01
#     topic_share                                        topic_terms  sum_terms
# 0     0.288750  [elect, immigr, financ, money, frank, justic, ...      0.536
# 1     0.161747  [internet, tough, interest, learn, speak, impo...      0.650
# 2     0.296053  [import, discrimin, racial, internet, civil, s...      0.730
# 3     0.253461  [disabl, decis, leadership, elect, action, sch...      0.568
#
# G2008oct15
#     topic_share                                        topic_terms  sum_terms
# 0     0.153627  [agreement, trade, import, dollar, invest, red...      0.466
# 1     0.363430  [school, spend, insur, money, employ, afford, ...      0.403
# 2     0.196234  [small, plumber, wealth, exampl, addit, cours,...      0.563
# 3     0.286712  [import, energi, econom, crisi, tough, indepen...      0.443
# D2000jan25
#     topic_share                                        topic_terms  sum_terms
# 0     0.210137  [import, prescript, negat, attack, benefit, ac...      0.907
# 1     0.380391  [medicaid, money, insur, propos, financ, medic...      0.876
# 2     0.169245  [fight, special, interest, import, money, insu...      0.918
# 3     0.240122  [budget, attack, negat, second, propos, medica...      0.887
#
# R2015aug06
#     topic_share                                        topic_terms  sum_terms
# 0     0.244017  [growth, econom, protect, actual, respons, cle...      0.587
# 1     0.300302  [secur, border, social, money, budget, elect, ...      0.689
# 2     0.191240  [proud, total, leader, illeg, israel, father, ...      0.705
# 3     0.264246  [militari, fight, megyn, chief, cours, command...      0.610
#
# R2007jun05
#     topic_share                                        topic_terms  sum_terms
# 0     0.254402  [nuclear, money, terror, weapon, major, fight,...      0.538
# 1     0.252882  [militari, saddam, interest, hussein, strong, ...      0.557
# 2     0.210518  [enforc, school, import, belief, actual, borde...      0.598
# 3     0.282164  [secur, immigr, spend, border, illeg, english,...      0.616
#
# R2012feb22
#     topic_share                                        topic_terms  sum_terms
# 0     0.211383  [weapon, nuclear, sanction, israel, oppos, cle...      0.611
# 1     0.310702  [money, spend, school, control, actual, import...      0.590
# 2     0.168702  [budget, balanc, involv, dollar, oppos, defens...      0.673
# 3     0.309211  [border, illeg, number, secur, spend, requir, ...      0.466
#
# R2008jan24
#     topic_share                                        topic_terms  sum_terms
# 0     0.369468  [economi, second, spend, perman, proud, concer...      0.507
# 1     0.207835  [money, spend, group, dollar, market, increas,...      0.573
# 2     0.209441  [insur, secur, social, qaeda, privat, money, b...      0.629
# 3     0.213245  [china, level, import, protect, general, econo...      0.672
#
# R2008jan30
#     topic_share                                        topic_terms  sum_terms
# 0     0.292001  [secur, whole, withdraw, timet, troop, import,...      0.567
# 1     0.201693  [wrong, money, foreign, dollar, china, qaeda, ...      0.534
# 2     0.284317  [ronald, economi, militari, money, foreign, sp...      0.589
# 3     0.222182  [spend, money, proud, particular, situat, resp...      0.615
#
# R2011oct18
#     topic_share                                        topic_terms  sum_terms
# 0     0.223818  [border, foreign, number, budget, individu, de...      0.638
# 1     0.222160  [economi, insur, certain, compani, market, pri...      0.616
# 2     0.297132  [illeg, immigr, herman, second, individu, oran...      0.666
# 3     0.256872  [energi, obamacar, econom, absolut, money, rep...      0.579
#
# G2016oct19
#     topic_share                                        topic_terms  sum_terms
# 0     0.224114  [money, nuclear, small, economi, wealthi, seri...      0.698
# 1     0.288993  [disast, trade, china, husband, worst, russia,...      0.511
# 2     0.274626  [border, syria, russian, clear, secur, elect, ...      0.604
# 3     0.212286  [amend, second, justic, immigr, tremend, stron...      0.690
#
# R2000jan07
#     topic_share                                        topic_terms  sum_terms
# 0     0.250103  [incom, corrupt, foreign, money, market, inter...      0.944
# 1     0.301544  [militari, import, mistak, interest, secur, mo...      0.956
# 2     0.215738  [citizen, school, social, secur, money, trade,...      0.915
# 3     0.232616  [internet, trade, taxat, market, incom, secur,...      0.935
#
# R2012jan23
#     topic_share                                        topic_terms  sum_terms
# 0     0.320350  [elect, economi, frank, speaker, regul, trade,...      0.588
# 1     0.204309  [capit, includ, exampl, incom, money, clear, p...      0.528
# 2     0.260774  [number, interest, success, whole, encourag, s...      0.561
# 3     0.214565  [freddi, speaker, import, attack, economi, str...      0.610
#
# R2016jan14
#     topic_share                                        topic_terms  sum_terms
# 0     0.326273  [militari, secur, elect, serious, interest, ra...      0.387
# 1     0.225732  [china, tariff, fight, economi, syrian, compan...      0.555
# 2     0.267923  [marco, immigr, actual, legal, group, dollar, ...      0.408
# 3     0.180073  [amend, second, money, general, compani, corpo...      0.532
#
# R2016jan28
#     topic_share                                        topic_terms  sum_terms
# 0     0.237915  [leader, radic, stage, terror, situat, chief, ...      0.507
# 1     0.222030  [attack, elect, actual, marco, defeat, militar...      0.435
# 2     0.336846  [immigr, amnesti, militari, legal, illeg, rebu...      0.514
# 3     0.203134  [account, protect, econom, decis, elect, impor...      0.526
#
# R2011nov22
#     topic_share                                        topic_terms  sum_terms
# 0     0.320397  [legal, secur, border, money, clear, qaeda, im...      0.378
# 1     0.282470  [secur, interest, militari, pakistan, border, ...      0.507
# 2     0.178711  [command, spend, budget, chief, troop, terrori...      0.520
# 3     0.218394  [nuclear, weapon, serious, israel, syria, regi...      0.498
#
# G1992oct13
#     topic_share                                        topic_terms  sum_terms
# 0     0.259754  [propos, abort, crisi, georg, period, insur, d...      0.621
# 1     0.203146  [school, choos, privat, parent, taxpay, admir,...      0.692
# 2     0.243093  [georg, invest, crisi, truth, compani, insur, ...      0.576
# 3     0.293836  [georg, econom, environment, trickl, standard,...      0.568
#
# G1992oct11
#     topic_share                                        topic_terms  sum_terms
# 0     0.332024  [money, economi, interest, import, concern, ec...      0.462
# 1     0.254942  [incom, control, econom, invest, militari, cre...      0.501
# 2     0.212886  [spend, defens, propos, control, growth, money...      0.616
# 3     0.188144  [industri, second, whole, capit, school, futur...      0.638
#
# R2000jan10
#     topic_share                                        topic_terms  sum_terms
# 0     0.312566  [father, interest, young, trade, china, castro...      0.674
# 1     0.226844  [money, africa, moral, everyth, wrong, militar...      0.788
# 2     0.271262  [militari, secur, import, money, social, parti...      0.692
# 3     0.189329  [pledg, elect, declar, whole, inform, clear, d...      0.844
#
# R2012jan08
#     topic_share                                        topic_terms  sum_terms
# 0     0.243513  [import, union, member, oversea, anyth, experi...      0.875
# 1     0.272501  [econom, energi, money, incom, secur, spend, a...      0.845
# 2     0.197036  [cours, actual, elect, money, anyth, attack, m...      0.877
# 3     0.286943  [elect, spend, speaker, budget, experi, welfar...      0.926
#
# R2007oct09
#     topic_share                                        topic_terms  sum_terms
# 0     0.143233  [agreement, product, technolog, control, absol...      0.466
# 1     0.192829  [union, worker, immigr, illeg, trade, tariff, ...      0.560
# 2     0.268082  [nuclear, energi, economi, market, money, prot...      0.332
# 3     0.395858  [spend, trade, secur, economi, control, econom...      0.383
#
# R2007oct21
#     topic_share                                        topic_terms  sum_terms
# 0     0.221604  [social, secur, money, privat, ronald, benefit...      0.683
# 1     0.229935  [mayor, involv, fight, absolut, individu, inte...      0.707
# 2     0.260558  [insur, privat, price, foreign, benefit, socia...      0.714
# 3     0.287862  [strong, militari, secur, spend, proud, brough...      0.701
#
# D2008jan04
#     topic_share                                        topic_terms  sum_terms
# 0     0.259701  [troop, specif, elect, secur, militari, effort...      0.426
# 1     0.199609  [energi, georg, reduc, interest, compani, effi...      0.473
# 2     0.233236  [fight, interest, compani, corpor, insur, clas...      0.606
# 3     0.307171  [nuclear, weapon, actual, pakistan, respons, i...      0.511
#
# R2011nov09
#     topic_share                                        topic_terms  sum_terms
# 0     0.247143  [market, regul, sector, energi, privat, actual...      0.563
# 1     0.325087  [price, market, number, currenc, insur, capit,...      0.460
# 2     0.218806  [economi, fanni, freddi, dollar, bailout, numb...      0.554
# 3     0.208973  [secur, incom, propos, money, china, price, ch...      0.557
# R2011dec10
#     topic_share                                        topic_terms  sum_terms
# 0     0.249405  [number, insur, money, privat, anyth, model, c...      0.553
# 1     0.278303  [secur, social, economi, consist, elect, impor...      0.578
# 2     0.256238  [individu, oughta, obamacar, frank, import, fi...      0.598
# 3     0.216093  [truth, israel, palestinian, difficult, probab...      0.575
#
# D1999oct27
#     topic_share                                        topic_terms  sum_terms
# 0     0.367041  [school, financ, money, propos, import, though...      0.828
# 1     0.131286  [propos, futur, spend, money, school, import, ...      0.829
# 2     0.193962  [fight, tipper, financ, strong, spend, futur, ...      0.936
# 3     0.307700  [leader, import, futur, second, fight, thought...      0.959
#
# G2012oct11
#     topic_share                                        topic_terms  sum_terms
# 0     0.280148  [sanction, weapon, nuclear, troop, fight, rega...      0.559
# 1     0.307338  [class, incom, small, wealthi, spend, money, d...      0.598
# 2     0.232951  [medicar, senior, social, secur, benefit, prop...      0.602
# 3     0.182416  [secur, respons, exact, clear, investig, train...      0.536
#
# G1976oct15
#     topic_share                                        topic_terms  sum_terms
# 0     0.288912  [final, dollar, control, import, whole, foreig...      0.463
# 1     0.219838  [concern, hundr, thousand, dollar, spend, defe...      0.502
# 2     0.345276  [leadership, inflat, unemploy, budget, senior,...      0.461
# 3     0.145975  [waterg, suggest, spend, respons, budget, conc...      0.672
#
# R2007may15
#     topic_share                                        topic_terms  sum_terms
# 0     0.225899  [reduc, tortur, illeg, money, elect, certain, ...      0.657
# 1     0.253201  [spend, decis, depart, inform, general, listen...      0.617
# 2     0.333685  [border, attack, secur, situat, interest, diff...      0.641
# 3     0.187229  [abort, stage, secur, actual, immigr, depart, ...      0.645
#
# R2000jan15
#     topic_share                                        topic_terms  sum_terms
# 0     0.236171  [china, medic, ronald, dollar, choos, trade, s...      0.451
# 1     0.296542  [school, interest, money, agricultur, product,...      0.387
# 2     0.264514  [school, money, social, secur, import, benefit...      0.470
# 3     0.202780  [money, control, parent, wrong, deduct, moral,...      0.412
#
# R2007dec12
#     topic_share                                        topic_terms  sum_terms
# 0     0.193993  [energi, independ, global, reduc, strength, ec...      0.493
# 1     0.278150  [spend, secur, import, money, actual, control,...      0.481
# 2     0.270050  [school, teacher, learn, defens, market, impor...      0.441
# 3     0.257830  [border, trade, destroy, secur, threat, produc...      0.477
#
# R2015oct28
#     topic_share                                        topic_terms  sum_terms
# 0     0.207190  [regul, fantasi, field, everyth, small, import...      0.554
# 1     0.319872  [money, secur, social, medicar, economi, benef...      0.551
# 2     0.177529  [spend, exact, dollar, leadership, borrow, sec...      0.450
# 3     0.295362  [budget, fight, stage, actual, money, incom, n...      0.367
#
# D2007jul23
#     topic_share                                        topic_terms  sum_terms
# 0     0.285956  [money, compani, commit, elect, advoc, minimum...      0.508
# 1     0.238303  [school, teacher, daughter, actual, energi, im...      0.643
# 2     0.246658  [troop, respons, equal, solut, civil, effort, ...      0.532
# 3     0.229080  [messag, belief, proud, certain, import, achie...      0.450
#
# R2012jan19
#     topic_share                                        topic_terms  sum_terms
# 0     0.216317  [compani, capit, energi, regul, money, econom,...      0.562
# 1     0.329871  [abort, protect, militari, speaker, veteran, n...      0.518
# 2     0.280993  [illeg, immigr, medicaid, legal, level, elect,...      0.477
# 3     0.172811  [insur, privat, return, wrong, begin, individu...      0.689
#
# G2004oct13
#     topic_share                                        topic_terms  sum_terms
# 0     0.205347  [border, secur, increas, oppon, citizen, class...      0.610
# 1     0.262292  [secur, medicar, fiscal, lower, import, fight,...      0.511
# 2     0.288516  [budget, economi, decis, small, propos, school...      0.405
# 3     0.243858  [citizen, protect, oppon, measur, money, reduc...      0.500
#
# D2008jan15
#     topic_share                                        topic_terms  sum_terms
# 0     0.236147  [school, yucca, mountain, dollar, consist, alr...      0.441
# 1     0.231397  [energi, nuclear, plant, young, militari, mone...      0.442
# 2     0.300645  [troop, respons, fight, interest, combat, clea...      0.405
# 3     0.231730  [money, interest, energi, lobbyist, obvious, s...      0.453
#
# G1960oct13
#     topic_share                                        topic_terms  sum_terms
# 0     0.181798  [suggest, therefor, possibl, matsu, quemoy, co...      0.626
# 1     0.348985  [growth, maintain, econom, concern, union, sov...      0.557
# 2     0.081515  [indic, control, union, cours, statement, adva...      0.563
# 3     0.387600  [indic, suggest, quemoy, communist, statement,...      0.520
#
# G1960oct07
#     topic_share                                        topic_terms  sum_terms
# 0     0.230273  [strength, econom, sixti, respons, economi, co...      0.533
# 1     0.183014  [defens, general, twenti, strong, second, comm...      0.705
# 2     0.303473  [communist, effect, economi, regard, indic, el...      0.522
# 3     0.283241  [leadership, khrushchev, field, cours, concern...      0.520
#
# G1984oct07
#     topic_share                                        topic_terms  sum_terms
# 0     0.226540  [increas, propos, human, incom, defens, alread...      0.599
# 1     0.280860  [secur, social, regard, budget, benefit, elect...      0.633
# 2     0.201359  [religi, privat, decis, leadership, propos, sc...      0.621
# 3     0.291233  [deficit, interest, economi, econom, growth, b...      0.580
#
# D2007aug07
#     topic_share                                        topic_terms  sum_terms
# 0     0.224065  [worker, infrastructur, bridg, union, organ, s...      0.484
# 1     0.209913  [money, member, china, protect, negoti, organ,...      0.482
# 2     0.250291  [trade, labor, agreement, import, nafta, china...      0.551
# 3     0.316215  [pakistan, foreign, begin, qaeda, troop, afgha...      0.472
#
# R2011dec15
#     topic_share                                        topic_terms  sum_terms
# 0     0.307131  [actual, justic, learn, import, frank, economi...      0.514
# 1     0.221960  [speaker, wrong, welfar, second, alreadi, abor...      0.592
# 2     0.226716  [weapon, decis, nuclear, danger, suprem, israe...      0.595
# 3     0.244194  [budget, militari, money, balanc, foreign, str...      0.536
#
# G1992oct15
#     topic_share                                        topic_terms  sum_terms
# 0     0.186049  [weapon, money, spend, econom, number, elect, ...      0.718
# 1     0.313053  [control, economi, fight, number, growth, spen...      0.539
# 2     0.258491  [school, spend, money, privat, control, involv...      0.739
# 3     0.242402  [deficit, export, invest, money, increas, spen...      0.698
#
# G1996oct09
#     topic_share                                        topic_terms  sum_terms
# 0     0.324057  [medicar, protect, budget, environ, balanc, in...      0.473
# 1     0.211267  [economi, strong, clear, medicar, secur, schoo...      0.464
# 2     0.234545  [foreign, capit, economi, unemploy, profit, in...      0.377
# 3     0.230159  [capit, welfar, invest, empower, enterpris, in...      0.461
#
# D2000feb21
#     topic_share                                        topic_terms  sum_terms
# 0     0.229282  [insur, medicar, money, surplus, benefit, offe...      0.692
# 1     0.257644  [school, racial, teacher, profil, polic, crime...      0.647
# 2     0.259560  [action, affirm, african, import, school, exem...      0.711
# 3     0.253503  [invest, propos, urban, special, major, enforc...      0.712
#
# G2012oct16
#     topic_share                                        topic_terms  sum_terms
# 0     0.140213  [china, manufactur, trade, insur, compani, sma...      0.576
# 1     0.276467  [small, futur, trade, actual, energi, china, i...      0.478
# 2     0.351613  [young, economi, invest, number, import, schoo...      0.445
# 3     0.231718  [energi, incom, class, immigr, lower, product,...      0.580
# R2012jan26
#     topic_share                                        topic_terms  sum_terms
# 0     0.266352  [freddi, actual, economi, fanni, medicin, seco...      0.452
# 1     0.244241  [legal, immigr, deport, illeg, grandmoth, sect...      0.477
# 2     0.266025  [insur, import, involv, space, particular, spe...      0.458
# 3     0.223384  [space, money, invest, trade, secur, actual, s...      0.499
#
# R2015nov10
#     topic_share                                        topic_terms  sum_terms
# 0     0.257913  [budget, militari, spend, import, china, dolla...      0.599
# 1     0.258982  [money, actual, bigger, energi, compani, dolla...      0.464
# 2     0.223632  [economi, growth, econom, higher, control, rep...      0.624
# 3     0.259455  [elect, capit, money, anyth, syria, frank, exe...      0.479
#
# G1984oct11
#     topic_share                                        topic_terms  sum_terms
# 0     0.246328  [soviet, union, negoti, nuclear, leader, reduc...      0.815
# 1     0.291171  [futur, interest, strong, leadership, young, e...      0.701
# 2     0.244679  [civil, refer, action, interest, strong, young...      0.738
# 3     0.217824  [secur, protect, everyth, covert, central, abs...      0.687
#
# G2004oct05
#     topic_share                                        topic_terms  sum_terms
# 0     0.231209  [compani, insur, increas, medicar, medic, resp...      0.524
# 1     0.274852  [clear, terrorist, saddam, hussein, afghanista...      0.399
# 2     0.312968  [terror, wrong, import, major, weapon, sponsor...      0.337
# 3     0.180980  [benefit, prescript, signific, senior, avail, ...      0.465
#
# G2012oct03
#     topic_share                                        topic_terms  sum_terms
# 0     0.241778  [deficit, class, small, militari, spend, inves...      0.388
# 1     0.166802  [incom, number, economi, money, budget, lower,...      0.498
# 2     0.219589  [insur, compani, deduct, preexist, condit, boa...      0.401
# 3     0.371848  [medicar, insur, money, obamacar, lower, senio...      0.482
#
# D1999dec17
#     topic_share                                        topic_terms  sum_terms
# 0     0.267066  [import, economi, futur, leadership, commit, s...      0.598
# 1     0.331528  [school, propos, voucher, respons, violenc, pa...      0.668
# 2     0.134640  [parent, young, patient, increas, insur, stron...      0.730
# 3     0.266763  [insur, elect, direct, decid, respons, increas...      0.658
#
# R2007may03
#     topic_share                                        topic_terms  sum_terms
# 0     0.257064  [spend, elect, militari, altern, thought, cour...      0.585
# 1     0.206474  [ronald, nuclear, weapon, reduc, greatest, num...      0.711
# 2     0.265114  [decis, import, certain, money, foreign, terro...      0.625
# 3     0.271346  [secur, immigr, border, abort, absolut, strong...      0.547
#
# G2016oct09
#     topic_share                                        topic_terms  sum_terms
# 0     0.230848  [muslim, heard, berni, wonder, attack, african...      0.782
# 1     0.235257  [import, interest, carri, anyth, wrong, includ...      0.760
# 2     0.252837  [insur, compani, number, inner, tremend, disas...      0.802
# 3     0.281076  [money, russian, syria, elect, corpor, attack,...      0.664
#
# G2016oct04
#     topic_share                                        topic_terms  sum_terms
# 0     0.273391  [nuclear, foreign, weapon, foundat, russian, e...      0.456
# 1     0.235136  [enforc, crimin, immigr, border, foundat, econ...      0.486
# 2     0.297308  [penni, russia, vladimir, defend, elain, leade...      0.427
# 3     0.194163  [secur, refuge, privat, syrian, import, safeti...      0.466
#
# R2011oct11
#     topic_share                                        topic_terms  sum_terms
# 0     0.267163  [reserv, frank, repeal, obamacar, spend, berna...      0.512
# 1     0.356258  [economi, spend, china, trade, experi, financi...      0.423
# 2     0.172826  [solut, small, wrong, regul, money, biggest, l...      0.475
# 3     0.201033  [energi, capit, manufactur, actual, number, in...      0.474
#
# R2000jan26
#     topic_share                                        topic_terms  sum_terms
# 0     0.224249  [import, money, technolog, financ, decis, unbo...      0.490
# 1     0.239077  [moral, abort, trade, organ, actual, concern, ...      0.420
# 2     0.247026  [china, favor, individu, status, reduc, money,...      0.424
# 3     0.289711  [school, money, social, secur, militari, spend...      0.503
#
# R2007dec09
#     topic_share                                        topic_terms  sum_terms
# 0     0.177090  [insur, castro, citizen, employ, recogn, actua...      0.771
# 1     0.334743  [hispan, elect, militari, young, number, money...      0.692
# 2     0.204240  [school, hispan, parent, audienc, import, econ...      0.866
# 3     0.283937  [illeg, legal, immigr, border, secur, citizen,...      0.809
#
# R2012jan16
#     topic_share                                        topic_terms  sum_terms
# 0     0.308239  [secur, social, militari, actual, incom, young...      0.550
# 1     0.241286  [money, spend, budget, balanc, defens, economi...      0.554
# 2     0.229447  [second, amend, economi, regul, felon, compani...      0.609
# 3     0.221045  [immigr, money, learn, defens, standard, citiz...      0.586
#
# G2004oct08
#     topic_share                                        topic_terms  sum_terms
# 0     0.184145  [small, gentleman, futur, terrorist, deficit, ...      0.554
# 1     0.372323  [weapon, saddam, threat, hussein, mistak, gene...      0.483
# 2     0.188798  [secur, spend, money, increas, recess, fight, ...      0.514
# 3     0.254917  [decis, balanc, protect, import, budget, fight...      0.557
#
# D2007sep09
#     topic_share                                        topic_terms  sum_terms
# 0     0.160719  [latino, begin, worker, wrong, leadership, und...      0.696
# 1     0.275540  [immigr, latin, worker, human, number, import,...      0.671
# 2     0.344410  [latino, hispan, compani, insur, import, speak...      0.638
# 3     0.219340  [border, immigr, secur, legal, comprehens, cer...      0.600
#
# G1960oct21
#     topic_share                                        topic_terms  sum_terms
# 0     0.186366  [communist, africa, eisenhow, econom, relat, c...      0.645
# 1     0.297666  [soviet, space, union, indic, previous, khrush...      0.585
# 2     0.192410  [soviet, union, fifti, communist, indic, deter...      0.588
# 3     0.323457  [latin, fifti, econom, strong, relat, oppos, e...      0.637
#
# D2008apr16
#     topic_share                                        topic_terms  sum_terms
# 0     0.315289  [import, elect, listen, econom, georg, generat...      0.406
# 1     0.207404  [secur, charli, economi, current, propos, clas...      0.525
# 2     0.200620  [militari, futur, import, obvious, deserv, int...      0.404
# 3     0.276684  [attack, former, energi, georg, clear, stateme...      0.415
#
# G2000oct17
#     topic_share                                        topic_terms  sum_terms
# 0     0.173989  [money, spend, propos, number, strong, protect...      0.615
# 1     0.431522  [school, medicar, money, senior, secur, parent...      0.541
# 2     0.242956  [death, action, affirm, strong, patient, insur...      0.644
# 3     0.151533  [parent, compani, insur, strong, young, involv...      0.588
#
# G2000oct03
#     topic_share                                        topic_terms  sum_terms
# 0     0.231920  [money, spend, elect, strong, interest, result...      0.521
# 1     0.295552  [secur, social, senior, medicar, money, prescr...      0.566
# 2     0.209857  [school, class, parent, budget, surplus, secur...      0.464
# 3     0.262663  [decis, propos, technolog, compani, import, el...      0.501
#
# D1999dec19
#     topic_share                                        topic_terms  sum_terms
# 0     0.236158  [secur, social, medicar, retir, money, consid,...      0.894
# 1     0.227056  [oppos, consid, retir, qualiti, voucher, limit...      0.896
# 2     0.321328  [money, school, propos, voucher, experi, reali...      0.944
# 3     0.215469  [televis, second, medicar, limit, money, avera...      0.870
#
# G1996oct06
#     topic_share                                        topic_terms  sum_terms
# 0     0.183907  [commit, saddam, money, young, mention, troop,...      0.473
# 1     0.291491  [weapon, bradi, assault, commiss, watch, futur...      0.321
# 2     0.241718  [school, money, medicar, increas, budget, spen...      0.445
# 3     0.284241  [budget, futur, welfar, number, balanc, elect,...      0.349
# D2008jan31
#     topic_share                                        topic_terms  sum_terms
# 0     0.269165  [immigr, economi, actual, comprehens, approach...      0.517
# 1     0.199464  [afford, insur, interest, number, actual, impe...      0.554
# 2     0.154938  [compani, insur, certain, negoti, import, begi...      0.590
# 3     0.376432  [import, clear, concern, respons, interest, ge...      0.479
#
# R2016mar10
#     topic_share                                        topic_terms  sum_terms
# 0     0.257037  [secur, social, muslim, worker, strong, budget...      0.454
# 1     0.237280  [elect, interest, listen, foreign, fight, fran...      0.521
# 2     0.257962  [trade, school, negoti, import, contribut, num...      0.478
# 3     0.246740  [israel, number, china, militari, generat, com...      0.448
#
# R2000mar02
#     topic_share                                        topic_terms  sum_terms
# 0     0.224264  [proud, import, clear, speak, school, exampl, ...      0.963
# 1     0.332374  [money, school, account, heart, speak, exampl,...      0.963
# 2     0.216517  [account, exampl, school, militari, import, pa...      0.963
# 3     0.226818  [parent, clear, school, militari, speak, heart...      0.964
#
# G1992oct19
#     topic_share                                        topic_terms  sum_terms
# 0     0.285525  [spend, budget, interest, taxpay, foreign, bal...      0.510
# 1     0.293554  [class, money, saddam, hussein, trade, spend, ...      0.388
# 2     0.152353  [econom, economi, industri, elect, control, tr...      0.564
# 3     0.268555  [mistak, night, crisi, econom, second, money, ...      0.398
#
# G2008sep26
#     topic_share                                        topic_terms  sum_terms
# 0     0.298513  [spend, nuclear, import, control, weapon, defe...      0.393
# 1     0.260279  [money, general, import, fundament, strategi, ...      0.320
# 2     0.250400  [energi, russian, economi, crisi, dollar, impo...      0.343
# 3     0.190817  [troop, afghanistan, pakistan, strategi, qaeda...      0.491
#
# D2016feb11
#     topic_share                                        topic_terms  sum_terms
# 0     0.243649  [crimin, justic, african, economi, young, clea...      0.508
# 1     0.212741  [effort, econom, money, proud, suggest, dollar...      0.471
# 2     0.268196  [import, disagre, secur, major, terribl, every...      0.560
# 3     0.275342  [agreement, incom, clear, result, african, tui...      0.467
#
# D2007jun28
#     topic_share                                        topic_terms  sum_terms
# 0     0.283976  [school, money, poverti, invest, heard, incom,...      0.444
# 1     0.238629  [import, orlean, break, elimin, minor, effort,...      0.507
# 2     0.273776  [justic, african, exist, prison, katrina, alre...      0.457
# 3     0.203104  [rebuild, orlean, african, respons, teacher, s...      0.538
#
# G2000oct05
#     topic_share                                        topic_terms  sum_terms
# 0     0.226316  [number, import, budget, surplus, signific, de...      0.417
# 1     0.271795  [class, berni, parent, credit, import, benefit...      0.397
# 2     0.311459  [militari, weapon, chief, import, exact, clear...      0.444
# 3     0.190416  [secur, social, privat, control, generat, futu...      0.469
#
# G2000oct11
#     topic_share                                        topic_terms  sum_terms
# 0     0.211892  [foreign, strong, spend, thought, exact, secon...      0.499
# 1     0.170549  [troop, enforc, decis, situat, standard, guess...      0.530
# 2     0.394404  [import, militari, money, interest, strong, cr...      0.484
# 3     0.223139  [local, level, profil, racial, exampl, serious...      0.492
#
# D2008jan21
#     topic_share                                        topic_terms  sum_terms
# 0     0.244776  [money, lobbyist, interest, economi, incom, cr...      0.440
# 1     0.266523  [present, import, credit, interest, transform,...      0.430
# 2     0.231698  [poverti, trade, african, fight, equal, social...      0.404
# 3     0.257006  [compani, import, insur, elect, anybodi, invol...      0.538
#
# D2007sep26
#     topic_share                                        topic_terms  sum_terms
# 0     0.260568  [troop, combat, diplomaci, immigr, protect, lo...      0.362
# 1     0.290136  [import, certain, clear, leadership, author, d...      0.376
# 2     0.230001  [negoti, tortur, mistak, privat, second, econo...      0.376
# 3     0.219311  [secur, social, enforc, import, number, respon...      0.482
#
# D2016feb04
#     topic_share                                        topic_terms  sum_terms
# 0     0.218571  [absolut, cours, includ, particular, coalit, y...      0.640
# 1     0.333343  [economi, compani, corpor, fight, trade, actua...      0.455
# 2     0.216282  [nuclear, committe, proud, actual, absolut, el...      0.476
# 3     0.231804  [interest, money, agreement, trade, major, cla...      0.491
#
# G1996oct16
#     topic_share                                        topic_terms  sum_terms
# 0     0.223246  [secur, social, money, medicar, budget, spend,...      0.626
# 1     0.293832  [economi, oppos, trade, capit, agreement, econ...      0.474
# 2     0.174080  [young, credit, watch, decid, privat, elect, e...      0.636
# 3     0.308769  [welfar, increas, medicar, import, respons, bu...      0.509
#
# R2012jan07
#     topic_share                                        topic_terms  sum_terms
# 0     0.239297  [money, spend, corrupt, energi, increas, desig...      0.629
# 1     0.217123  [invest, leadership, command, troop, number, e...      0.450
# 2     0.308403  [marriag, relationship, sector, privat, trade,...      0.538
# 3     0.235149  [elect, command, vision, chief, afghanistan, f...      0.515
#
# D2007jun03
#     topic_share                                        topic_terms  sum_terms
# 0     0.248403  [militari, troop, number, secur, young, diplom...      0.392
# 1     0.223453  [money, insur, hospit, compani, dollar, price,...      0.440
# 2     0.271612  [author, speak, import, intellig, effort, mora...      0.357
# 3     0.262866  [import, clear, energi, interest, depend, inte...      0.360
#
# R2016mar03
#     topic_share                                        topic_terms  sum_terms
# 0     0.221294  [second, amend, fight, level, command, chief, ...      0.708
# 1     0.287790  [foreign, china, marco, dollar, defens, nomine...      0.584
# 2     0.271789  [number, money, elect, obamacar, cours, listen...      0.655
# 3     0.219121  [stage, immigr, stronger, negoti, biggest, exa...      0.656
#
# D2007aug19
#     topic_share                                        topic_terms  sum_terms
# 0     0.211947  [trade, georg, agreement, second, respons, eno...      0.673
# 1     0.247661  [teacher, money, school, perform, prayer, impo...      0.718
# 2     0.290236  [troop, decis, actual, begin, georg, author, m...      0.574
# 3     0.250161  [nuclear, weapon, pakistan, interest, hypothet...      0.541
#
# R2011nov12
#     topic_share                                        topic_terms  sum_terms
# 0     0.342984  [pakistan, militari, afghanistan, command, int...      0.533
# 1     0.216527  [troop, absolut, afghanistan, fight, secur, co...      0.641
# 2     0.209147  [nuclear, weapon, covert, militari, clear, act...      0.677
# 3     0.231312  [pakistan, china, foreign, clear, number, econ...      0.638
#
# R2015dec15
#     topic_share                                        topic_terms  sum_terms
# 0     0.207060  [militari, leadership, destroy, strategi, elec...      0.351
# 1     0.238206  [refuge, secur, marco, syrian, defens, safeti,...      0.308
# 2     0.254821  [border, immigr, legal, secur, serious, syria,...      0.312
# 3     0.299929  [terrorist, terror, attack, radic, islam, figh...      0.343
#
#
# ******** G2012oct22  failed to be modelled
#
# G1988sep25
#     topic_share                                        topic_terms  sum_terms
# 0     0.156076  [insur, citizen, import, respons, attack, prop...      0.707
# 1     0.364310  [spend, strong, convent, weapon, serious, sovi...      0.470
# 2     0.266427  [school, leadership, thousand, begin, involv, ...      0.511
# 3     0.213203  [control, intern, noriega, decis, crime, produ...      0.654
#
# D2007apr26
#     topic_share                                        topic_terms  sum_terms
# 0     0.255469  [begin, money, focus, terror, militari, proud,...      0.460
# 1     0.221325  [number, readi, second, brian, energi, third, ...      0.535
# 2     0.254069  [decis, secur, avail, includ, cours, effort, a...      0.503
# 3     0.269142  [weapon, import, respons, threat, leadership, ...      0.415
# R2007nov28
#     topic_share                                        topic_terms  sum_terms
# 0     0.230999  [crime, mayor, school, number, abort, polic, r...      0.491
# 1     0.251963  [immigr, illeg, crime, stage, employ, legal, d...      0.520
# 2     0.188865  [enforc, pledg, spend, messag, general, indivi...      0.440
# 3     0.328394  [secur, money, militari, spend, anybodi, impor...      0.436
#
# G1976oct22
#     topic_share                                        topic_terms  sum_terms
# 0     0.274459  [general, decis, qualifi, militari, indic, sev...      0.625
# 1     0.169087  [leadership, respons, involv, purpos, present,...      0.606
# 2     0.238283  [increas, inflat, decis, import, elect, purpos...      0.582
# 3     0.318206  [unemploy, money, welfar, major, control, incr...      0.535
#
# D2016mar09
#     topic_share                                        topic_terms  sum_terms
# 0     0.266465  [industri, incom, school, import, economi, mon...      0.707
# 1     0.199560  [immigr, comprehens, secur, citizenship, longe...      0.763
# 2     0.257367  [deport, everyth, deserv, immigr, possibl, eco...      0.544
# 3     0.276597  [interest, money, number, worker, small, certa...      0.566
#
# D2007oct30
#     topic_share                                        topic_terms  sum_terms
# 0     0.239157  [nuclear, compani, money, import, insur, elect...      0.335
# 1     0.198296  [secur, social, georg, energi, school, econom,...      0.308
# 2     0.241161  [diplomaci, experi, nuclear, troop, weapon, ac...      0.282
# 3     0.321423  [secur, young, actual, everyth, respons, immig...      0.270
#
# R1999oct22
#     topic_share                                        topic_terms  sum_terms
# 0     0.298017  [school, parent, teacher, propos, bureaucrat, ...      0.743
# 1     0.260671  [trade, china, chines, favor, exampl, clear, i...      0.723
# 2     0.194669  [money, social, econom, control, moral, techno...      0.645
# 3     0.246639  [interest, foreign, frank, actual, poverti, in...      0.648
#
# G2004sep30
#     topic_share                                        topic_terms  sum_terms
# 0     0.196248  [korea, nuclear, messag, oppon, interest, impo...      0.401
# 1     0.428352  [wrong, troop, iraqi, strong, messag, terror, ...      0.348
# 2     0.168227  [hussein, saddam, laden, troop, usama, attack,...      0.475
# 3     0.207156  [weapon, nuclear, prolifer, destruct, threat, ...      0.488
#
# R2016feb25
#     topic_share                                        topic_terms  sum_terms
# 0     0.259082  [israel, foreign, libya, number, exampl, money...      0.449
# 1     0.168364  [korea, budget, economi, dollar, balanc, milit...      0.449
# 2     0.328570  [immigr, border, audit, illeg, fight, justic, ...      0.420
# 3     0.248022  [obamacar, insur, compani, watch, money, justi...      0.466
#
# D2004jan22
#     topic_share                                        topic_terms  sum_terms
# 0     0.232825  [fight, intend, whole, direct, attack, fought,...      0.681
# 1     0.212642  [militari, saddam, hussein, member, respons, c...      0.666
# 2     0.274230  [compani, money, budget, school, peter, actual...      0.662
# 3     0.280303  [protect, respons, wrong, interest, import, co...      0.655
#
# D2007dec13
#     topic_share                                        topic_terms  sum_terms
# 0     0.265849  [trade, import, energi, relationship, human, a...      0.466
# 1     0.238113  [prioriti, economi, budget, growth, respons, f...      0.353
# 2     0.244532  [school, corpor, fight, class, compani, everyt...      0.464
# 3     0.251510  [medicar, restor, secur, teacher, money, forei...      0.411
#
# R1999dec02
#     topic_share                                        topic_terms  sum_terms
# 0     0.246547  [internet, karen, standard, current, independ,...      0.514
# 1     0.256484  [internet, protect, control, anyth, increas, i...      0.492
# 2     0.228000  [secur, social, retir, propos, benefit, accoun...      0.654
# 3     0.268967  [interest, spend, elect, special, militari, yo...      0.560
#
# D2008feb21
#     topic_share                                        topic_terms  sum_terms
# 0     0.173910  [interest, clear, economi, import, offer, numb...      0.791
# 1     0.263680  [border, import, immigr, learn, thousand, resp...      0.838
# 2     0.221920  [insur, afford, number, secur, respons, intere...      0.863
# 3     0.340495  [import, cheer, interest, voter, actual, speci...      0.656
#
# G1960sep26
#     topic_share                                        topic_terms  sum_terms
# 0     0.204788  [teacher, propos, school, major, third, commit...      0.740
# 1     0.312409  [effect, hundr, growth, twenti, committe, sugg...      0.579
# 2     0.172455  [growth, suggest, dollar, advoc, secur, produc...      0.678
# 3     0.310383  [secur, social, dollar, societi, second, sixti...      0.550
#
# R2007aug05
#     topic_share                                        topic_terms  sum_terms
# 0     0.236969  [militari, solut, islam, extrem, fight, cours,...      0.694
# 1     0.248642  [money, incom, reduc, second, number, economi,...      0.753
# 2     0.244875  [secur, number, mistak, economi, probabl, cert...      0.637
# 3     0.269507  [georg, thought, citizen, individu, depend, pa...      0.729
#
# R2007sep05
#     topic_share                                        topic_terms  sum_terms
# 0     0.192137  [troop, attack, terrorist, certain, general, h...      0.710
# 1     0.243605  [respons, mayor, protect, second, crime, elect...      0.597
# 2     0.287856  [illeg, border, immigr, secur, thought, crime,...      0.661
# 3     0.276406  [nuclear, militari, number, experi, weapon, fo...      0.562
#
# D2007dec04
#     topic_share                                        topic_terms  sum_terms
# 0     0.239378  [worker, interest, iranian, weapon, corpor, ch...      0.316
# 1     0.265133  [leverag, number, china, import, diplomat, eco...      0.338
# 2     0.252942  [china, enforc, immigr, secur, employ, certain...      0.334
# 3     0.241296  [china, trade, immigr, english, legal, speak, ...      0.333
#
# D2000jan17
#     topic_share                                        topic_terms  sum_terms
# 0     0.274262  [discrimin, civil, african, latino, poverti, l...      0.844
# 1     0.246422  [african, latino, asian, justic, leader, futur...      0.950
# 2     0.229148  [futur, african, civil, young, latino, justic,...      0.911
# 3     0.250169  [heart, young, human, poverti, discrimin, hono...      0.900
#
# R1999dec13
#     topic_share                                        topic_terms  sum_terms
# 0     0.224201  [money, spend, import, china, protect, market,...      0.703
# 1     0.222964  [school, citizen, moral, declar, ronald, basic...      0.581
# 2     0.302796  [product, china, intern, trade, heart, market,...      0.577
# 3     0.250042  [interest, commit, moral, young, money, school...      0.500
#
# R2011sep12
#     topic_share                                        topic_terms  sum_terms
# 0     0.220402  [incom, energi, economi, number, lower, compet...      0.468
# 1     0.360202  [secur, social, execut, obamacar, money, spend...      0.603
# 2     0.168112  [economi, reserv, privat, sector, parent, spen...      0.637
# 3     0.251284  [dollar, young, actual, compani, medicar, soun...      0.483
#
# R2008jan06
#     topic_share                                        topic_terms  sum_terms
# 0     0.188304  [leadership, skill, certain, decis, dollar, en...      0.577
# 1     0.296026  [secur, experi, decis, immigr, illeg, futur, i...      0.447
# 2     0.288575  [spend, elect, incom, lower, economi, money, a...      0.535
# 3     0.227096  [secur, truth, import, cours, concern, spent, ...      0.493
#
# D2015dec19
#     topic_share                                        topic_terms  sum_terms
# 0     0.168701  [coalit, attack, weapon, safeti, major, enforc...      0.408
# 1     0.352041  [invest, actual, assad, syria, muslim, intelli...      0.322
# 2     0.217088  [import, secur, economi, offer, particular, en...      0.294
# 3     0.262180  [class, afford, number, major, economi, involv...      0.326
#
# D2015nov14
#     topic_share                                        topic_terms  sum_terms
# 0     0.223446  [comprehens, steagal, economi, glass, attack, ...      0.412
# 1     0.314338  [major, young, class, money, chanc, intern, fi...      0.360
# 2     0.249025  [intellig, threat, difficult, militari, leader...      0.413
# 3     0.213192  [afford, incom, money, actual, economi, defend...      0.485
# D2015oct13
#     topic_share                                        topic_terms  sum_terms
# 0     0.222677  [economi, protect, actual, comprehens, money, ...      0.335
# 1     0.219386  [immigr, money, young, actual, billionair, inc...      0.378
# 2     0.252948  [syria, veteran, import, fought, econom, assad...      0.334
# 3     0.304979  [climat, social, secur, class, address, elect,...      0.281
#
# R2011sep07
#     topic_share                                        topic_terms  sum_terms
# 0     0.291560  [secur, social, border, commit, privat, econom...      0.544
# 1     0.227769  [parent, import, immigr, respons, human, solut...      0.626
# 2     0.267685  [ronald, interest, budget, border, money, lear...      0.546
# 3     0.212996  [secur, execut, number, econom, social, probab...      0.669
#
# R1999dec06
#     topic_share                                        topic_terms  sum_terms
# 0     0.260084  [trade, china, organ, secur, interest, liberti...      0.680
# 1     0.209572  [price, elect, foreign, ronald, encourag, prod...      0.736
# 2     0.262982  [money, school, control, secur, prosper, worke...      0.681
# 3     0.267415  [interest, incom, internet, special, contribut...      0.747
#
# R2011sep05
#     topic_share         topic_terms  sum_terms
# 0     0.122741  [individu, growth]        1.0
# 1     0.122603  [individu, growth]        1.0
# 2     0.443304  [individu, growth]        1.0
# 3     0.311319  [growth, individu]        1.0
#
# R2011aug11
#     topic_share                                        topic_terms  sum_terms
# 0     0.277205  [fight, marriag, nuclear, result, wrong, incre...      0.457
# 1     0.272814  [economi, spend, money, marriag, capit, corpor...      0.535
# 2     0.213306  [leadership, budget, growth, afghanistan, bala...      0.499
# 3     0.228980  [border, immigr, repeal, secur, illeg, suggest...      0.513
#
# R2008jan10
#     topic_share                                        topic_terms  sum_terms
# 0     0.235563  [foreign, money, fight, militari, futur, numbe...      0.491
# 1     0.271272  [israel, interest, nuclear, period, import, pa...      0.508
# 2     0.307181  [spend, immigr, ronald, economi, strong, illeg...      0.574
# 3     0.185985  [border, secur, illeg, command, econom, seriou...      0.667
#
# R2008jan05
#     topic_share                                        topic_terms  sum_terms
# 0     0.279180  [price, energi, charli, dollar, number, market...      0.417
# 1     0.239978  [insur, foreign, afford, compani, reduc, money...      0.488
# 2     0.188638  [illeg, border, immigr, secur, legal, crime, e...      0.649
# 3     0.292258  [amnesti, militari, islam, attack, secur, radi...      0.513
#
# D2016jan17
#     topic_share                                        topic_terms  sum_terms
# 0     0.204444  [polic, agenda, justic, crimin, second, final,...      0.652
# 1     0.256596  [young, frank, major, andrea, corrupt, alreadi...      0.426
# 2     0.260373  [insur, actual, afford, privat, andrea, class,...      0.531
# 3     0.282638  [includ, money, region, fight, weapon, pleas, ...      0.439
#
# D2008feb26
#     topic_share                                        topic_terms  sum_terms
# 0     0.255553  [afford, independ, accur, cover, import, achie...      0.570
# 1     0.199243  [standard, nafta, actual, agreement, worker, c...      0.572
# 2     0.289791  [begin, clear, interest, strong, decis, obviou...      0.436
# 3     0.255417  [insur, interest, afford, compani, money, spec...      0.637

# %%
from gensim.test.utils import common_corpus, common_dictionary

lda = LdaMulticore(common_corpus,
                   id2word = common_dictionary,
                   num_topics = 5,
                   workers = 3,
                   passes = 10,
                   decay = 0.77)


def processed_docs(filename, count):
        
    df = pd.read_csv(directory+"/"+filename)
    
    processed_docs = []
    
    for row in df["speech"]:
        sentence = []
        for word in row.split(" "):
            x = re.sub('[^a-zA-Z]+', '', word)
            if len(x) > 4:
                if str(nltk.pos_tag([x])[0][1])[0] in ["N","J"]:
                    if x not in stop_words:
                        sentence.append(x)
        processed_docs.append(sentence)
        
    
    dictionary = gensim.corpora.Dictionary(processed_docs)
    dictionary.filter_extremes(no_above = 0.8)
    bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

    for i in range(len(rev_train)):
        top_topics = lda_train.get_document_topics(train_corpus[i], minimum_probability=0.0)
        topic_vec = [top_topics[i][1] for i in range(20)]
        topic_vec.extend([rev_train.iloc[i].real_counts]) # counts of reviews for restaurant
        topic_vec.extend([len(rev_train.iloc[i].text)]) # length review
        train_vecs.append(topic_vec)

    
    
    #lda_model = LdaMulticore(bow_corpus,
    #                 num_topics = 5,
    #                 id2word = dictionary,
    #                 workers = 3,
    #                 passes = 10,
    #                 decay = 0.74,
    #                 minimum_probability = 0.01)        
        
    
    topic_value = []
    for i in lda_model.print_topics():
        words = []
        value = 0
        out_list = i[1].split("+")
        for x in out_list:
            num = literal_eval(x.split("*")[0][1:])
            value+=num
        for x in out_list:
            t = x.replace('"', " ").strip(" ").split("*")[1]
            words.append(t.strip(" "))
        stringed = ','.join(words)
        value = round(value, 5)
        topic_value.append((value, stringed))
    
    topic_value = topic_value.sort(reverse=True)
    
    return topic_value
# Out:
#   File "<ipython-input-1-b51fa5211882>", line 33
#     top_topics = lda_train.get_document_topics(train_corpus[i], minimum_probability=0.0)
#              ^
# IndentationError: expected an indented block

# %%
directory = "debate_data/debates_preprocessed"

iteration = 0
details = []
for filename in os.listdir(directory):
    this_file = []
    if filename.endswith(".csv"):
        print(filename)
        this_file.append(filename)
        result = processed_docs(filename, iteration)
        this_file.append(result)
        for i in result:
            print(i)
    details.append(this_file)
    iteration+=1
# Out:
# D2000jan08.csv
# [(0.864, ' financ, control, elect, introduc, improv, trust, protect, medicar, provid, decis'), (0.858, ' medicar, fight, futur, child, budget, dollar, cover, interest, medicaid, protect'), (0.799, ' school, teacher, import, increas, propos, child, access, learn, night, europ'), (0.852, ' money, agricultur, leadership, secur, insur, number, militari, exampl, import, interest')]
# G1988oct05.csv
# [(0.728, ' interest, import, number, militari, poverti, dollar, advic, train, oppos, contribut'), (0.711, ' trade, experi, secur, budget, deficit, qualif, accomplish, hostag, invest, disagre'), (0.697, ' commit, futur, environment, defens, money, environ, union, protect, child, enforc'), (0.626, ' situat, market, clean, spend, respons, treati, concern, prepar, ticket, leadership')]
# R2007sep27.csv
# [(0.831, ' penalti, death, crime, school, involv, declar, control, level, round, individu'), (0.683, ' illeg, individu, welfar, immigr, border, anybodi, rememb, societi, economi, author'), (0.796, ' troop, prison, secur, money, amend, account, border, coupl, militari, respons'), (0.772, ' import, doctor, child, econom, number, suggest, enforc, especi, photo, destruct')]
# R2015sep16.csv
# [(0.279, ' child, money, listen, radic, interest, budget, heard, russia, gotten, balanc'), (0.374, ' militari, import, marijuana, amend, respons, success, secur, medic, border, anybodi'), (0.314, ' fight, immigr, stage, leadership, leader, ronald, absolut, spend, chief, illeg'), (0.326, ' elect, syria, weapon, agreement, respond, china, belief, appoint, truth, crimin')]
# R2011jun13.csv
# [(0.495, ' obamacar, repeal, price, space, spend, individu, natur, ethanol, group, absolut'), (0.529, ' economi, secur, propos, market, level, growth, energi, organ, guard, incom'), (0.451, ' privat, medicar, sector, money, bankruptci, futur, protect, interest, libya, union'), (0.473, ' money, command, learn, number, child, militari, exampl, manufactur, marriag, probabl')]
# G2008oct07.csv
# [(0.566, ' elimin, afghanistan, troop, fanni, provid, fought, afghan, excess, singl, confid'), (0.468, ' spend, respons, money, militari, increas, crisi, effect, prevent, exampl, import'), (0.551, ' energi, economi, russia, behavior, invest, budget, econom, fundament, drill, weapon'), (0.467, ' insur, import, afford, secur, situat, child, interest, propos, laden, organ')]
# R2011sep22.csv
# [(0.544, ' secur, corpor, incom, afford, danger, replac, subsidi, throw, natur, depart'), (0.546, ' obamacar, economi, child, insur, border, repeal, capit, econom, secur, absolut'), (0.619, ' illeg, money, israel, immigr, number, militari, exact, respond, stage, level'), (0.478, ' school, union, control, parent, dollar, compani, option, pakistan, decis, spent')]
# D2007nov15.csv
# [(0.488, ' trade, china, control, corpor, intend, mistak, mountain, yucca, nafta, worri'), (0.707, ' cheer, import, teacher, child, school, absolut, energi, fundament, attack, musharraf'), (0.467, ' number, pakistan, worker, militari, begin, interest, immigr, illeg, agreement, driver'), (0.476, ' secur, troop, solut, elect, protect, privaci, stage, respons, border, suprem')]
# D2004jan29.csv
# [(0.831, ' islam, repres, benefit, leadership, attack, independ, nafta, corpor, child, import'), (0.828, ' trade, militari, worker, hussein, terror, intern, saddam, mental, intellig, corpor'), (0.872, ' insur, medicar, child, protect, chief, result, command, moder, textil, leadership'), (0.789, ' secur, elect, weapon, number, import, destruct, lawyer, account, messag, intend')]
# R2016feb06.csv
# [(0.343, ' mention, border, group, draft, domain, respons, commit, secur, absolut, anyth'), (0.33, ' korea, money, command, chief, elect, missil, militari, marco, properti, defens'), (0.3, ' militari, import, strike, enforc, insur, budget, illeg, obamacar, increas, immigr'), (0.314, ' veteran, execut, requir, polic, leadership, sunni, launch, child, respond, singl')]
# D2016jan25.csv
# [(0.724, ' afford, muslim, child, secur, mental, owner, found, level, impact, elect'), (0.694, ' insur, compani, interest, dollar, organ, possibl, hospit, pocket, corpor, terrorist'), (0.703, ' incom, econom, fight, import, wealth, experi, weapon, generat, worth, thought'), (0.64, ' economi, veteran, attack, employ, school, privat, protect, militari, absolut, futur')]
# D2016apr14.csv
# [(0.567, ' israel, absolut, terrorist, contribut, incom, deserv, invest, releas, return, tomorrow'), (0.498, ' secur, weapon, elect, exact, break, syria, barrier, effort, crime, libya'), (0.513, ' import, energi, provid, clean, suprem, fossil, compani, action, number, level'), (0.537, ' money, decis, interest, attack, respond, minimum, respons, frack, commit, climat')]
# R1999oct28.csv
# [(0.944, ' school, incom, money, provid, parent, resourc, child, insur, spend, found'), (0.949, ' interest, dollar, child, clean, money, found, financ, liberti, averag, insur'), (0.853, ' militari, ambassador, charg, insur, dollar, import, money, parent, resourc, bureaucrat'), (0.937, ' import, pleas, teacher, bureaucrat, spend, averag, insur, clean, resourc, charg')]
# R2016feb13.csv
# [(0.53, ' economi, import, appoint, obamacar, scalia, threat, spent, situat, russia, tremend'), (0.551, ' elect, growth, econom, poverti, suprem, focus, privat, domain, frank, flexibl'), (0.496, ' money, immigr, border, secur, compani, incom, control, medicaid, spend, mistak'), (0.593, ' fight, listen, child, attack, ronald, illeg, amnesti, weapon, action, execut')]
# G1988oct13.csv
# [(0.635, ' spend, budget, weapon, deficit, agricultur, gotten, defens, pledg, unilater, member'), (0.503, ' clean, appoint, defens, proud, import, sound, label, water, concern, trust'), (0.597, ' secur, decis, convent, negoti, futur, strateg, deterr, margaret, control, reduct'), (0.495, ' child, welfar, heard, mother, freez, begin, andrea, elect, exampl, increas')]
# R2000feb15.csv
# [(0.533, ' money, spend, daughter, leader, result, corpor, fundament, opinion, china, defin'), (0.508, ' interest, speak, abort, trust, leadership, strateg, attack, event, exampl, pleas'), (0.606, ' finish, militari, secur, import, commit, experi, excus, death, crime, heart'), (0.651, ' elect, respons, messag, group, integr, internet, access, individu, moratorium, orient')]
# G2008oct02.csv
# [(0.452, ' economi, maverick, econom, fundament, weapon, leader, mortgag, climat, commit, crisi'), (0.508, ' energi, increas, anyth, ticket, money, clean, credit, israel, independ, invest'), (0.55, ' afghanistan, troop, number, deregul, regard, militari, neighborhood, budget, afford, command'), (0.458, ' energi, child, break, oppos, produc, import, regul, danger, strategi, compani')]
# G2016sep26.csv
# [(0.546, ' polic, lester, learn, nobodi, hanniti, concern, crimin, prepar, probabl, inner'), (0.528, ' money, trade, releas, wealthi, audit, propos, invest, return, respond, produc'), (0.559, ' compani, import, tremend, defend, fight, economi, cyber, thousand, experi, websit'), (0.502, ' china, everyth, number, incom, regul, watch, mayor, heard, stamen, spent')]
# G1980sep21.csv
# [(0.813, ' money, propos, specif, militari, inflationari, economi, respons, incent, spend, necessari'), (0.648, ' energi, individu, begin, project, amend, independ, regard, indic, budget, industri'), (0.808, ' increas, spend, figur, reduc, industri, import, addit, perhap, price, consumpt'), (0.73, ' simpli, inflat, possibl, econom, confront, pocket, amount, dollar, increas, sourc')]
# D2016mar06.csv
# [(0.581, ' import, everyth, manufactur, industri, barrier, econom, elect, proud, violenc, trust'), (0.519, ' child, crimin, absolut, account, prioriti, investig, hundr, respons, mother, number'), (0.676, ' money, corpor, export, trade, begin, crime, agreement, import, disastr, teacher'), (0.578, ' water, school, polic, compani, provid, dollar, child, economi, infrastructur, invest')]
# D2000mar01.csv
# [(0.681, ' elect, militari, polic, propos, amnesti, initi, fight, situat, depart, individu'), (0.786, ' import, internet, money, discrimin, immigr, interest, school, access, commit, fundament'), (0.753, ' thought, disabl, mistak, leadership, speak, learn, child, deepli, econom, group'), (0.529, ' taiwan, financ, frank, decis, elect, quota, action, experi, provid, latino')]
# G2008oct15.csv
# [(0.5, ' trade, agreement, dollar, wealth, spread, decis, organ, import, focus, fought'), (0.566, ' import, energi, independ, increas, reduc, associ, plumber, floor, thought, fight'), (0.434, ' school, futur, economi, voucher, propos, teacher, crisi, mortgag, econom, disagre'), (0.52, ' spend, insur, money, provid, afford, budget, abort, child, exampl, employ')]
# D2000jan25.csv
# [(0.751, ' propos, attack, budget, welfar, price, medicar, protect, medicaid, benefit, number'), (0.746, ' child, insur, financ, import, increas, deficit, invest, prescript, welfar, advis'), (0.811, ' money, negat, fight, voucher, provid, attack, school, accept, provis, medicaid'), (0.722, ' choos, interest, incom, medicaid, compani, fought, substanc, exampl, pharmaceut, medic')]
# R2015aug06.csv
# [(0.614, ' border, elect, leader, respons, negoti, becam, exact, correct, spend, privat'), (0.542, ' immigr, illeg, israel, bless, import, advantag, enforc, frank, facebook, economi'), (0.495, ' militari, money, stage, trust, proud, enemi, mother, radic, rememb, father'), (0.513, ' secur, budget, megyn, fight, protect, growth, balanc, econom, retir, incom')]
# R2007jun05.csv
# [(0.471, ' immigr, money, spend, number, terror, member, child, ronald, respons, illeg'), (0.384, ' enforc, saddam, elect, hussein, border, brother, begin, sacrific, provid, interest'), (0.424, ' militari, school, includ, medicin, exact, mayor, attack, accept, human, probabl'), (0.529, ' insur, secur, border, import, energi, fight, illeg, employ, independ, interest')]
# R2012feb22.csv
# [(0.505, ' budget, balanc, school, industri, involv, leader, oppos, defend, border, cathol'), (0.532, ' spend, child, weapon, control, bankruptci, manag, sanction, money, birth, entitl'), (0.502, ' illeg, includ, elect, import, attack, religi, enforc, immigr, depart, economi'), (0.558, ' syria, number, fight, provid, money, compani, troubl, futur, union, market')]
# R2008jan24.csv
# [(0.51, ' secur, proud, import, level, worri, invest, expand, project, independ, interest'), (0.496, ' spend, increas, favor, protect, worth, consum, china, trade, reduc, corpor'), (0.616, ' economi, money, spend, dollar, china, amend, benefit, confid, citizen, weapon'), (0.588, ' insur, econom, frank, industri, militari, elect, perman, budget, group, balanc')]
# R2008jan30.csv
# [(0.564, ' spend, secur, import, border, endors, leadership, address, money, economi, econom'), (0.466, ' budget, includ, situat, absolut, interest, decid, monetari, charg, built, weigh'), (0.562, ' ronald, economi, militari, troop, manag, insur, command, chief, elect, thought'), (0.586, ' money, proud, timet, suppos, regard, energi, experi, revolut, leader, cheer')]
# R2011oct18.csv
# [(0.72, ' border, secur, econom, import, analysi, israel, resourc, experi, herman, oppos'), (0.645, ' illeg, energi, immigr, economi, insur, magnet, defens, orang, repeal, replac'), (0.689, ' absolut, number, spend, incom, letter, negoti, compani, child, respond, foundat'), (0.625, ' individu, money, market, speak, obamacar, budget, herman, latino, group, product')]
# G2016oct19.csv
# [(0.516, ' syria, fight, foundat, deport, compani, outsmart, appoint, depart, mention, tremend'), (0.587, ' mosul, money, anyth, haiti, russia, militari, everyth, tougher, wealthi, experi'), (0.574, ' border, amend, trade, decis, secur, nobodi, defend, protect, violenc, number'), (0.506, ' immigr, economi, disast, massiv, invest, child, elect, repeal, undocu, saudi')]
# R2000jan07.csv
# [(0.878, ' ambassador, begin, market, elect, negat, money, child, chechnya, charit, import'), (0.816, ' control, decis, trade, concern, interest, author, school, return, citizen, child'), (0.876, ' militari, import, product, internet, moratorium, secur, mistak, involv, choos, gambl'), (0.896, ' incom, corrupt, chariti, commerc, taxat, internet, citizen, gambl, money, charit')]
# R2012jan23.csv
# [(0.481, ' speaker, interest, attack, space, leadership, incom, price, fight, absolut, market'), (0.506, ' economi, freddi, militari, trade, frank, enterpris, historian, obamacar, suffer, provid'), (0.494, ' capit, number, regul, pretti, lobbi, money, import, cuban, consult, includ'), (0.553, ' elect, compani, illeg, unemploy, learn, encourag, school, vision, histor, weapon')]
# R2016jan14.csv
# [(0.389, ' attack, money, militari, polic, islam, everyth, recogn, budget, radic, economi'), (0.479, ' fight, compani, marco, elect, interest, protect, corpor, group, mother, count'), (0.483, ' tariff, number, refuge, stage, amend, control, enforc, absolut, border, impos'), (0.491, ' china, maria, secur, trade, child, mention, listen, execut, watch, regul')]
# R2016jan28.csv
# [(0.473, ' attack, secur, budget, growth, number, exact, border, energi, pleas, mention'), (0.457, ' illeg, marco, leader, respond, amend, command, protect, introduc, treat, chief'), (0.628, ' militari, amnesti, enforc, elect, radic, decis, stage, respons, terror, destroy'), (0.628, ' immigr, defeat, veteran, import, liberti, megyn, group, citizenship, rebuild, religi')]
# R2011nov22.csv
# [(0.488, ' israel, troop, pakistan, china, radic, liberti, afghanistan, balanc, privat, recogn'), (0.681, ' secur, border, threat, terror, number, illeg, alreadi, defens, trust, amnesti'), (0.567, ' militari, weapon, money, spend, intellig, increas, qaeda, pakistan, regim, budget'), (0.499, ' afghanistan, syria, terrorist, attack, crime, command, respons, econom, interest, chief')]
# G1992oct13.csv
# [(0.675, ' defens, invest, requir, decis, admir, school, choos, exampl, mistak, effort'), (0.811, ' propos, respond, economi, limit, simpli, privat, environ, respons, taxpay, listen'), (0.692, ' abort, crisi, import, choos, attack, child, qualifi, waffl, concentr, parent'), (0.673, ' econom, environment, truth, increas, trickl, insur, standard, troubl, offer, futur')]
# G1992oct11.csv
# [(0.56, ' money, incom, econom, militari, demonstr, futur, europ, spend, commit, charact'), (0.557, ' experi, invest, economi, interest, deficit, mistak, china, fight, medicar, strength'), (0.506, ' child, secur, concern, nobodi, decis, import, capit, listen, anyth, credit'), (0.531, ' control, spend, defens, number, industri, russia, dollar, execut, retrain, troop')]
# R2000jan10.csv
# [(0.688, ' respons, china, decis, africa, author, elect, negat, achiev, school, truth'), (0.755, ' money, militari, castro, internet, death, provid, telecommun, choos, declar, librari'), (0.742, ' child, pledg, import, father, interest, filter, spend, adult, surplus, everyth'), (0.849, ' listen, trade, secur, group, medium, appreci, propos, stage, castro, fidel')]
# R2012jan08.csv
# [(0.806, ' money, medicar, econom, entitl, energi, oversea, labor, price, trust, secur'), (0.848, ' spend, incom, experi, budget, welfar, stood, choos, price, chanc, money'), (0.726, ' speaker, import, union, liberti, fight, career, found, poverti, entir, anyth'), (0.868, ' elect, regul, limit, member, involv, attack, dollar, oversea, trust, secur')]
# R2007oct09.csv
# [(0.455, ' union, industri, militari, worker, requir, member, interest, spend, probabl, budget'), (0.483, ' economi, control, market, product, absolut, protect, immigr, import, tariff, illeg'), (0.478, ' trade, spend, money, technolog, china, agreement, benefit, export, dollar, oversea'), (0.52, ' secur, econom, energi, child, insur, independ, compani, trust, target, depend')]
# R2007oct21.csv
# [(0.698, ' insur, privat, involv, stage, individu, retir, fought, secur, account, crisi'), (0.724, ' school, child, spend, militari, troop, mayor, parent, present, crime, bankrupt'), (0.739, ' marriag, ronald, amend, learn, price, spent, realiz, coupl, mayor, individu'), (0.612, ' secur, money, fight, proud, dollar, interest, absolut, import, benefit, happi')]
# D2008jan04.csv
# [(0.58, ' specif, charli, child, experi, troop, belief, alreadi, patient, insur, militari'), (0.569, ' respons, crosstalk, respond, action, attack, qaida, lobbyist, enorm, prolifer, pakistan'), (0.508, ' fight, elect, weapon, reduc, secur, interest, pakistan, consequ, effort, musharraf'), (0.597, ' energi, compani, corpor, rememb, deliv, money, absolut, interest, economi, effici')]
# R2011nov09.csv
# [(0.483, ' freddi, market, fanni, level, insur, student, medicaid, patient, number, price'), (0.48, ' price, spend, china, profit, money, market, manufactur, crisi, taxpay, trade'), (0.548, ' economi, secur, bailout, dollar, corpor, energi, number, frank, repeal, individu'), (0.505, ' capit, sector, regul, privat, europ, croni, market, longer, respons, relationship')]
# R2011dec10.csv
# [(0.654, ' import, secur, number, regul, trust, energi, learn, illeg, singl, yahoo'), (0.603, ' speaker, money, obamacar, privat, insur, spend, amend, societi, growth, frank'), (0.619, ' individu, truth, stage, oughta, israel, respons, elect, interest, outsid, school'), (0.613, ' fight, economi, consist, citizen, model, solut, return, level, histor, decis')]
# D1999oct27.csv
# [(0.885, ' import, leader, pleas, futur, thought, parent, elect, leadership, generat, favor'), (0.804, ' teacher, child, provid, money, propos, experi, tipper, dartmouth, doctor, school'), (0.877, ' surplus, school, medicar, exampl, insur, spend, money, cover, futur, propos'), (0.892, ' financ, fight, pollut, protect, patient, interest, child, insur, favor, leadership')]
# G2012oct11.csv
# [(0.542, ' medicar, number, militari, budget, regard, russia, ayatollah, guarante, studi, success'), (0.636, ' weapon, sanction, incom, economi, cathol, attack, marin, hospit, ambassador, faster'), (0.572, ' secur, troop, propos, interest, fight, exact, voucher, investig, loophol, afghanistan'), (0.542, ' respons, spend, wealthi, credibl, absolut, benefit, obamacar, defens, money, dollar')]
# G1976oct15.csv
# [(0.554, ' dollar, probabl, europ, independ, honor, hundr, loophol, incom, apolog, employ'), (0.612, ' control, thousand, suggest, oppon, committe, interest, ticket, audienc, statement, restor'), (0.691, ' leadership, concern, waterg, labor, respons, henri, embargo, voter, leagu, exampl'), (0.489, ' spend, inflat, defens, unemploy, effort, budget, meani, economi, domin, citizen')]
# R2007may15.csv
# [(0.564, ' secur, abort, spend, tortur, decis, depart, dollar, weapon, stage, increas'), (0.599, ' mayor, troop, situat, oppos, elect, illeg, child, money, begin, immigr'), (0.515, ' attack, elimin, listen, respons, militari, reach, singl, statement, china, solut'), (0.527, ' border, immigr, reduc, research, necessari, inform, requir, ronald, embryon, import')]
# R2000jan15.csv
# [(0.416, ' approach, incom, trade, effect, generat, steve, market, independ, money, budget'), (0.593, ' school, import, china, child, parent, money, concern, agricultur, militari, depart'), (0.466, ' secur, conduct, respons, surplus, veteran, corpor, compani, experi, treat, choos'), (0.554, ' money, interest, product, ethanol, provid, control, prayer, command, school, thoma')]
# R2007dec12.csv
# [(0.535, ' school, import, teacher, border, level, strength, elect, depart, probabl, fight'), (0.465, ' secur, reduc, militari, threat, incom, judgment, futur, technolog, corpor, child'), (0.485, ' spend, energi, independ, defens, budget, deficit, number, realiti, china, achiev'), (0.446, ' trade, market, economi, learn, spend, leadership, money, address, econom, import')]
# R2015oct28.csv
# [(0.493, ' compani, benefit, fantasi, exampl, break, truth, medium, concern, leadership, trust'), (0.477, ' medicar, regul, singl, secur, number, account, involv, generat, depart, corpor'), (0.562, ' stage, fight, everyth, exact, dollar, interest, energi, becki, result, import'), (0.583, ' money, incom, economi, budget, elect, spend, secur, balanc, leader, spent')]
# D2007jul23.csv
# [(0.653, ' money, import, compani, minimum, interest, leadership, insur, video, proud, increas'), (0.566, ' troop, messag, energi, militari, diplomaci, union, darfur, elizabeth, propos, solut'), (0.601, ' advoc, elect, begin, teacher, provid, fight, absolut, effort, cover, achiev'), (0.558, ' school, child, respons, marriag, number, entir, commit, draft, stage, region')]
# R2012jan19.csv
# [(0.447, ' speaker, money, compani, repeal, regul, contrast, obamacar, import, dollar, energi'), (0.452, ' protect, thought, medicaid, level, attack, mention, manufactur, sector, fight, anyth'), (0.496, ' veteran, elect, militari, releas, border, probabl, success, return, budget, nobodi'), (0.534, ' immigr, illeg, insur, econom, number, capit, economi, abort, corpor, internet')]
# G2004oct13.csv
# [(0.659, ' worker, fight, insur, benefit, import, laden, usama, school, grant, decis'), (0.682, ' child, money, protect, minimum, amend, afford, listen, terrorist, hospit, result'), (0.565, ' increas, citizen, medicar, choos, economi, budget, spend, earli, incom, relief'), (0.691, ' secur, border, oppon, marriag, societi, reduc, illeg, enforc, veteran, provid')]
# D2008jan15.csv
# [(0.458, ' energi, interest, fight, decis, provid, truth, leadership, lobbyist, voter, futur'), (0.455, ' money, respons, spoke, account, speak, involv, manag, struggl, absolut, inspir'), (0.485, ' import, everyth, militari, commit, dollar, begin, bankruptci, invest, urgent, exampl'), (0.44, ' school, child, yucca, mountain, combat, troop, plant, elect, alreadi, latino')]
# G1960oct13.csv
# [(0.557, ' communist, maintain, commit, treati, prestig, berlin, dollar, surrend, addit, fifti'), (0.594, ' indic, suggest, attack, concern, growth, advanc, oppos, complet, interest, defend'), (0.451, ' flight, quemoy, matsu, includ, indic, correct, money, exampl, twenti, confer'), (0.607, ' union, possibl, control, truman, subject, disarma, present, number, pescador, effort')]
# G1960oct07.csv
# [(0.575, ' express, regret, confer, summit, latin, concern, decis, flight, hundr, africa'), (0.614, ' sixti, elect, defend, economi, provid, indic, strength, attack, afford, period'), (0.559, ' econom, communist, assist, regard, effect, import, field, money, recess, strength'), (0.559, ' adequ, defens, suggest, dollar, prestig, respons, khrushchev, maintain, twenti, commit')]
# G1984oct07.csv
# [(0.605, ' interest, economi, inflat, poverti, found, rememb, refer, involv, judgment, thought'), (0.617, ' secur, child, propos, medicar, human, futur, religi, begin, belief, budget'), (0.557, ' increas, regard, budget, defens, abort, recoveri, dollar, possibl, econom, commiss'), (0.65, ' deficit, growth, leadership, reduc, increas, economi, environ, import, protect, econom')]
# D2007aug07.csv
# [(0.538, ' china, trade, afghanistan, pakistan, begin, possibl, enforc, picket, qaeda, proud'), (0.555, ' import, secur, worker, nafta, money, trade, union, lobbyist, negoti, corpor'), (0.602, ' infrastructur, troop, bridg, protect, member, invest, child, highway, rebuild, singl'), (0.657, ' cheer, labor, organ, agreement, trade, bargain, standard, fight, compani, worker')]
# R2011dec15.csv
# [(0.607, ' weapon, israel, militari, danger, import, appoint, experi, elect, privat, chose'), (0.6, ' decis, economi, trust, freddi, repeal, missil, lobbi, invest, level, econom'), (0.686, ' money, marriag, relationship, suprem, learn, leadership, energi, spend, number, success'), (0.448, ' speaker, pretti, balanc, decid, ronald, welfar, enterpris, budget, sponsor, consist')]
# G1992oct15.csv
# [(0.544, ' deficit, economi, increas, everyth, number, charact, control, absolut, exampl, oversea'), (0.52, ' money, elect, invest, interest, import, inner, privat, pension, defens, number'), (0.661, ' school, econom, budget, polic, specif, weapon, crime, export, learn, trade'), (0.579, ' spend, child, insur, growth, night, secur, fight, control, industri, cover')]
# G1996oct09.csv
# [(0.615, ' medicar, protect, balanc, environ, budget, incom, welfar, clean, suggest, elimin'), (0.605, ' economi, capit, invest, enterpris, haiti, doubl, chanc, board, reduc, accept'), (0.532, ' credit, inner, school, child, capit, provid, access, pollut, opinion, regul'), (0.474, ' alreadi, growth, properti, import, riski, scheme, futur, money, defens, tuition')]
# D2000feb21.csv
# [(0.669, ' school, insur, child, teacher, money, medicaid, crime, parent, anyth, effort'), (0.762, ' import, fight, profil, enforc, polic, number, quota, respond, voucher, action'), (0.567, ' school, action, affirm, invest, propos, medicar, exempt, surplus, money, avail'), (0.655, ' child, prevent, elect, coupl, privileg, offer, theori, penalti, divid, charg')]
# G2012oct16.csv
# [(0.6, ' economi, compani, import, china, futur, invest, price, bankrupt, natur, econom'), (0.515, ' candi, incom, immigr, illeg, attack, settl, increas, number, drill, respons'), (0.492, ' number, trade, worker, school, unemploy, deduct, violenc, money, employ, enforc'), (0.561, ' energi, deficit, product, invest, manufactur, secur, spend, level, reduc, comprehens')]
# R2012jan26.csv
# [(0.445, ' invest, israel, child, employ, border, respons, resourc, budget, success, speaker'), (0.469, ' space, import, deport, grandmoth, learn, involv, school, pretti, attack, grandfath'), (0.49, ' insur, freddi, trade, happi, economi, fanni, interest, relationship, medicin, puerto'), (0.538, ' money, immigr, privat, sector, illeg, group, spend, repeal, hispan, exampl')]
# R2015nov10.csv
# [(0.47, ' growth, regul, import, repeal, interest, frank, capit, economi, econom, syria'), (0.447, ' economi, balanc, budget, militari, child, china, incom, elect, dream, number'), (0.49, ' dollar, spend, nobodi, leadership, econom, destroy, stori, reserv, marco, maria'), (0.508, ' money, execut, trade, financi, crisi, minimum, energi, import, singl, control')]
# G1984oct11.csv
# [(0.653, ' union, propos, negoti, interest, everyth, leadership, absolut, address, econom, control'), (0.527, ' leader, protect, deliv, patriot, interest, favor, speak, action, deficit, nicaragua'), (0.565, ' futur, school, agreement, number, lebanon, secur, covert, separ, intellig, suprem'), (0.577, ' terror, embassi, weapon, refer, human, reduc, economi, religion, abort, child')]
# G2004oct05.csv
# [(0.576, ' weapon, saddam, hussein, import, attack, terrorist, terror, medic, connect, specif'), (0.416, ' effort, terror, afghanistan, divid, signific, respons, success, truth, credibl, elect'), (0.515, ' compani, child, medicar, insur, provid, benefit, marriag, prescript, defend, halliburton'), (0.439, ' secur, school, realiti, control, sanction, coalit, osama, laden, iraqi, thursday')]
# G2012oct03.csv
# [(0.574, ' medicar, deficit, deduct, regul, insur, revenu, elect, reduc, incom, dollar'), (0.523, ' insur, compani, economi, energi, number, train, provid, growth, afford, break'), (0.472, ' school, privat, approach, board, obamacar, frank, budget, econom, teacher, treatment'), (0.511, ' money, incom, medicaid, addit, spend, condit, preexist, secur, replac, militari')]
# D1999dec17.csv
# [(0.664, ' insur, religi, medium, child, decid, import, number, control, compani, poverti'), (0.724, ' medicar, medicaid, elect, propos, hospit, repres, money, discrimin, patient, voucher'), (0.698, ' school, teacher, voucher, improv, economi, afford, propos, leadership, provid, revolutionari'), (0.693, ' respons, commit, handl, fight, parent, surplus, research, space, violenc, involv')]
# R2007may03.csv
# [(0.832, ' ronald, import, secur, immigr, militari, thought, proud, heart, weapon, probabl'), (0.866, ' abort, choos, birth, entir, amend, heart, spend, import, elect, clone'), (0.821, ' terror, effort, islam, rememb, incom, spend, elect, secur, import, mistak'), (0.851, ' decis, spend, absolut, money, clone, complet, address, mistak, secur, amend')]
# G2016oct09.csv
# [(0.511, ' apolog, muslim, suprem, interest, effect, judgment, everyth, wonder, berni, latino'), (0.677, ' russia, money, compani, energi, anyth, inner, insur, corpor, assad, rebel'), (0.598, ' child, proud, elect, disast, attack, mosul, excus, honest, provis, nobodi'), (0.609, ' import, insur, syria, heard, tremend, absolut, obamacar, fight, anyon, classifi')]
# G2016oct04.csv
# [(0.514, ' penni, troop, russia, militari, intellig, dollar, syria, korea, secur, laden'), (0.467, ' weapon, foundat, vladimir, russia, leader, secur, refuge, begin, border, import'), (0.482, ' defend, enforc, immigr, insult, focus, polic, deport, driven, wonder, soldier'), (0.482, ' elain, economi, crimin, privat, return, polic, absolut, school, apolog, safer')]
# R2011oct11.csv
# [(0.423, ' frank, sector, capit, number, economist, insur, privat, revenu, decis, institut'), (0.561, ' econom, china, trade, innov, solut, bailout, effect, leader, replac, herman'), (0.469, ' spend, financi, bernank, charli, audit, increas, money, economi, absolut, spent'), (0.517, ' economi, repeal, reserv, energi, manufactur, regul, incom, dollar, currenc, action')]
# R2000jan26.csv
# [(0.383, ' abort, child, price, technolog, chines, steve, syria, karen, demand, thought'), (0.442, ' money, china, spend, militari, favor, incom, human, status, proud, improv'), (0.452, ' school, interest, standard, subsidi, corpor, student, discrimin, provid, inform, trust'), (0.392, ' import, control, trade, child, digniti, secur, barrier, surplus, effect, includ')]
# R2007dec09.csv
# [(0.672, ' hispan, audienc, elect, militari, strategi, import, success, recogn, futur, brave'), (0.698, ' school, parent, child, secur, border, learn, market, employ, hispan, mistak'), (0.808, ' illeg, immigr, border, money, number, spend, student, entir, teacher, protect'), (0.688, ' insur, citizen, chavez, castro, welcom, fought, economi, latin, afford, strength')]
# R2012jan16.csv
# [(0.522, ' money, spend, immigr, defens, militari, border, experi, author, illeg, citizen'), (0.422, ' economi, amend, invest, secur, balanc, recogn, speaker, enterpris, sector, liabil'), (0.431, ' suggest, taliban, attack, unemploy, market, deficit, negoti, pakistan, financi, welfar'), (0.431, ' incom, regul, learn, compani, enemi, releas, relat, requir, benefit, super')]
# G2004oct08.csv
# [(0.42, ' threat, militari, fight, patriot, spend, korea, saddam, chairman, hussein, thought'), (0.517, ' gentleman, medicar, budget, import, balanc, deficit, train, compani, danger, intellig'), (0.516, ' decis, child, mistak, troop, terrorist, listen, technolog, propos, respons, money'), (0.502, ' weapon, destruct, protect, saddam, research, hussein, homeland, decis, europ, secur')]
# D2007sep09.csv
# [(0.662, ' immigr, border, latin, secur, comprehens, relationship, provid, chavez, separ, rememb'), (0.666, ' latino, child, hispan, school, recogn, dream, contribut, futur, involv, proud'), (0.706, ' cheer, import, compani, insur, begin, number, commit, transit, human, latino'), (0.616, ' latino, worker, speak, troop, parent, trade, human, reach, brought, castro')]
# G1960oct21.csv
# [(0.551, ' fifti, strength, determin, poland, independ, elect, struggl, negoti, econom, india'), (0.572, ' communist, extend, judgment, defend, prestig, attack, withdraw, provid, chiang, field'), (0.596, ' africa, union, indic, europ, space, respons, secur, societi, twenti, eisenhow'), (0.509, ' latin, castro, econom, khrushchev, influenc, relat, concern, confer, recommend, ambassador')]
# D2008apr16.csv
# [(0.596, ' economi, elect, frustrat, absolut, statement, region, weapon, israel, engag, entir'), (0.55, ' import, secur, energi, incom, potenti, generat, individu, comment, attack, thought'), (0.55, ' commit, begin, number, crisi, money, polic, anybodi, secur, repres, reverend'), (0.497, ' charli, listen, deliv, interest, militari, figur, econom, provid, whatev, child')]
# G2000oct17.csv
# [(0.534, ' parent, child, school, propos, death, relief, benefit, involv, futur, prescript'), (0.621, ' money, school, spend, secur, quota, dollar, learn, measur, complet, divers'), (0.527, ' medicar, account, fight, trust, affirm, number, proud, action, import, requir'), (0.476, ' teacher, insur, compani, patient, militari, doctor, consequ, teach, price, control')]
# G2000oct03.csv
# [(0.499, ' medicar, number, interest, requir, account, abort, prioriti, explor, futur, learn'), (0.557, ' secur, trust, benefit, budget, respons, result, surplus, appoint, relief, child'), (0.531, ' school, import, prescript, compani, prosper, elect, exampl, privat, fight, child'), (0.589, ' money, propos, spend, decis, militari, oppos, invest, troop, serbia, chanc')]
# D1999dec19.csv
# [(0.853, ' money, propos, secur, oppos, spend, voucher, realiti, limit, trust, accept'), (0.662, ' child, retir, medicaid, teacher, replac, possibl, absolut, cover, access, avail'), (0.712, ' school, mistak, surplus, interest, medicar, premium, sanction, finish, apolog, averag'), (0.672, ' commit, insur, singl, experi, financ, improv, classroom, televis, qualiti, teacher')]
# G1996oct06.csv
# [(0.539, ' school, budget, commiss, lawyer, watch, balanc, rememb, secur, welfar, trial'), (0.546, ' child, respons, credit, commit, teacher, protect, tobacco, sometim, bosnia, reach'), (0.552, ' medicar, money, futur, weapon, spend, number, bradi, economi, assault, financ'), (0.475, ' increas, crime, elect, econom, thought, school, incom, packag, import, probabl')]
# D2008jan31.csv
# [(0.513, ' author, respons, economi, money, scatter, cover, child, school, experi, behalf'), (0.518, ' cheer, afford, insur, provid, number, import, leadership, premium, prevent, commit'), (0.584, ' immigr, interest, proud, anybodi, child, intend, comprehens, driver, mention, lobbyist'), (0.443, ' import, approach, concern, troop, compani, absolut, worker, inspector, parent, condit')]
# R2016mar10.csv
# [(0.476, ' trade, number, china, veteran, budget, elect, compani, absolut, anyth, exampl'), (0.386, ' worker, fight, listen, terrorist, replac, immigr, bipartisan, import, tremend, probabl'), (0.472, ' secur, interest, retir, muslim, negoti, child, generat, radic, islam, parent'), (0.444, ' school, money, nobodi, israel, endors, solut, attack, tariff, border, threat')]
# R2000mar02.csv
# [(0.678, ' money, china, taiwan, school, messag, comment, cathol, internet, receiv, requir'), (0.791, ' proud, roosevelt, theodor, independ, secur, heart, ronald, ambassador, exampl, messag'), (0.632, ' regret, import, limit, interest, anyth, missil, result, militari, ambassador, defens'), (0.688, ' child, account, trigger, enforc, sorri, parent, respons, polic, robertson, decis')]
# G1992oct19.csv
# [(0.552, ' money, trade, invest, increas, spend, agreement, incom, respons, glaspi, ambassador'), (0.598, ' econom, economi, trickl, deficit, relev, nobodi, pattern, leadership, suggest, break'), (0.507, ' mistak, spend, night, interest, anyth, budget, industri, saddam, hussein, child'), (0.451, ' thought, standard, elect, crisi, protect, taxpay, credit, lobbi, effici, interest')]
# G2008sep26.csv
# [(0.415, ' troop, spend, pakistan, crisi, qaeda, precondit, nobodi, elimin, agenc, petraeus'), (0.405, ' strategi, secur, afghanistan, interest, oppos, defeat, compani, judgment, respons, account'), (0.401, ' afghanistan, weapon, doubt, threat, region, control, econom, decis, defens, employ'), (0.43, ' import, energi, spend, dollar, increas, economi, russia, mention, invest, absolut')]
# D2016feb11.csv
# [(0.511, ' economi, incom, elect, result, relat, syria, number, china, agenda, especi'), (0.541, ' dollar, propos, polic, crimin, contribut, super, guarante, wealth, suggest, protect'), (0.579, ' agreement, immigr, everyth, compani, econom, proud, comprehens, unemploy, insur, school'), (0.538, ' child, secur, disagre, terribl, import, money, interest, provid, respons, disagr')]
# D2007jun28.csv
# [(0.643, ' child, respons, minor, incom, crimin, begin, recogn, warren, access, neglect'), (0.606, ' school, money, child, societi, teacher, poverti, singl, alreadi, prison, guarante'), (0.516, ' africa, break, minimum, trade, elimin, invest, effort, diseas, chanc, mandatori'), (0.638, ' import, orlean, cheer, rebuild, darfur, outsourc, level, dollar, corpor, insur')]
# G2000oct05.csv
# [(0.454, ' secur, retir, exact, generat, import, proud, money, chief, achiev, decis'), (0.526, ' militari, credit, number, commit, interest, signific, relationship, concern, result, budget'), (0.448, ' berni, respons, parent, benefit, school, child, surplus, medicar, address, encourag'), (0.446, ' import, oppon, effect, leadership, energi, night, propos, bipartisan, effort, futur')]
# G2000oct11.csv
# [(0.583, ' militari, interest, mission, clean, heart, absolut, account, involv, number, control'), (0.541, ' import, exampl, school, crime, singl, child, insur, credibl, futur, polic'), (0.562, ' child, troop, thought, situat, decis, level, israel, measur, disagre, relief'), (0.569, ' money, prioriti, profil, environ, mention, societi, consequ, convinc, leader, violenc')]
# D2008jan21.csv
# [(0.486, ' money, trade, elect, exact, lobbyist, perman, number, finish, absolut, transform'), (0.438, ' economi, propos, respons, oppos, provid, money, crisi, stimul, consist, enforc'), (0.559, ' import, poverti, present, singl, child, incom, cover, troop, everyth, combat'), (0.501, ' compani, interest, fight, insur, commit, credit, leader, militari, import, coverag')]
# D2007sep26.csv
# [(0.496, ' import, protect, privat, singl, stage, econom, enforc, economi, growth, divis'), (0.469, ' respons, child, tortur, entir, leadership, immigr, syria, diplomaci, experi, anybodi'), (0.491, ' secur, troop, interest, negoti, begin, commit, provid, number, energi, mistak'), (0.39, ' everyth, combat, militari, drink, sanction, budget, level, balanc, mission, approach')]
# D2016feb04.csv
# [(0.466, ' absolut, economi, agreement, death, penalti, afford, incom, money, trade, pretti'), (0.517, ' number, interest, voter, china, money, exact, financi, worri, includ, econom'), (0.459, ' fight, secur, troop, endors, speak, break, militari, syria, achiev, territori'), (0.577, ' veteran, elect, trade, corpor, compani, rachel, dollar, child, chuck, billionair')]
# G1996oct16.csv
# [(0.487, ' secur, increas, econom, manag, oppos, capit, futur, whatev, school, employ'), (0.529, ' medicar, economi, import, child, protect, chanc, hospit, credit, amend, budget'), (0.536, ' anyth, trade, access, agreement, number, interest, market, deficit, probabl, commiss'), (0.498, ' welfar, respons, budget, spend, money, quota, trust, watch, privat, disabl')]
# R2012jan07.csv
# [(0.57, ' marriag, amend, militari, vision, contracept, energi, veteran, infrastructur, suprem, increas'), (0.545, ' spend, china, relationship, marri, trade, regul, secur, everyth, compani, decid'), (0.535, ' command, chief, troop, economi, number, elect, afghanistan, stage, fight, manag'), (0.473, ' sector, corrupt, success, import, money, privat, experi, leadership, coupl, child')]
# D2007jun03.csv
# [(0.411, ' author, elect, respons, interest, veteran, afghanistan, finish, border, intellig, approach'), (0.455, ' militari, number, diplomaci, truth, provid, effort, school, spend, weapon, dollar'), (0.394, ' insur, child, unfortun, decis, requir, leadership, profit, husband, thought, avail'), (0.525, ' import, troop, money, price, speak, energi, inform, technolog, immedi, immigr')]
# R2016mar03.csv
# [(0.408, ' number, suprem, heard, defend, china, budget, megyn, includ, manufactur, liberti'), (0.449, ' school, stage, negoti, militari, leader, flexibl, worker, excus, weapon, level'), (0.451, ' elect, trade, dollar, attack, marco, respond, compani, space, proper, break'), (0.5, ' money, economi, amend, fight, spend, protect, hotel, anybodi, inform, moment')]
# D2007aug19.csv
# [(0.63, ' perform, school, prayer, hypothet, lobbyist, express, danger, money, engag, separ'), (0.652, ' child, money, experi, pakistan, militari, author, diplomaci, stage, number, disagre'), (0.722, ' troop, decis, import, interest, weapon, elect, moment, residu, courag, stake'), (0.6, ' teacher, trade, option, agreement, mistak, stabil, includ, iraqi, enorm, fundament')]
# R2011nov12.csv
# [(0.565, ' militari, decis, relationship, econom, absolut, action, defens, pakistani, assad, budget'), (0.558, ' weapon, tortur, threat, fight, money, market, dollar, network, elect, repres'), (0.618, ' pakistan, china, afghanistan, terrorist, number, situat, techniqu, covert, enhanc, combat'), (0.631, ' troop, command, chief, secur, includ, taliban, intellig, energi, europ, sorri')]
# R2015dec15.csv
# [(0.528, ' secur, fight, border, assad, chief, defeat, command, watch, regim, reckless'), (0.385, ' terrorist, marco, enforc, bernardino, import, internet, terror, phone, citizen, elect'), (0.388, ' radic, islam, refuge, syria, child, strength, china, trust, terror, anyth'), (0.405, ' attack, immigr, focus, militari, strategi, control, listen, leadership, destroy, involv')]
# G2012oct22.csv
# [(0.668, ' china, troop, intern, technolog, laden, trade, russia, provid, stood, invest'), (0.711, ' leadership, region, afghanistan, compani, oversea, worker, pressur, futur, exampl, weapon'), (0.733, ' israel, militari, sanction, spend, economi, interest, syria, veteran, region, consequ'), (0.578, ' number, budget, respons, threat, libya, exact, recogn, capabl, reduc, transit')]
# G1988sep25.csv
# [(0.483, ' provid, leadership, insur, involv, control, oppos, commit, judgment, increas, readi'), (0.427, ' weapon, thousand, hostag, youngster, patriot, import, thought, experi, suggest, terrorist'), (0.358, ' citizen, money, mistak, favor, propos, child, econom, strength, welfar, convent'), (0.509, ' spend, decis, begin, school, passion, market, furlough, simpli, dollar, abort')]
# D2007apr26.csv
# [(0.621, ' number, terror, attack, import, child, intern, effort, trust, determin, focus'), (0.643, ' brian, proud, respons, militari, mental, alreadi, leadership, requir, mention, region'), (0.535, ' secur, threat, mistak, money, engag, diplomaci, energi, enorm, troop, weapon'), (0.669, ' decis, begin, readi, chanc, leader, avail, iraqi, insur, teacher, number')]
# R2007nov28.csv
# [(0.615, ' illeg, crime, immigr, abort, school, child, import, number, secur, commit'), (0.536, ' spend, sanctuari, money, absolut, stage, reduc, probabl, messag, islam, audienc'), (0.5, ' mayor, singl, entitl, found, necessari, recogn, technolog, money, result, infrastructur'), (0.477, ' border, decis, enforc, tortur, protect, trade, citizen, vietnam, pledg, videotap')]
# G1976oct22.csv
# [(0.523, ' increas, indic, decis, respons, period, present, affair, interest, begin, sever'), (0.503, ' amend, handgun, crime, unemploy, sacrific, abort, growth, individu, member, decis'), (0.609, ' money, minor, burger, committe, energi, exampl, statement, enforc, instanc, addit'), (0.573, ' militari, inflat, import, accur, reduc, control, attorney, leadership, unemploy, elect')]
# D2016mar09.csv
# [(0.649, ' compani, bailout, overthrow, cuban, possibl, terrorist, attack, brother, oppos, learn'), (0.651, ' comprehens, immigr, incom, import, border, energi, number, secur, deserv, econom'), (0.724, ' money, immigr, interest, industri, karen, pleas, afford, respond, rescu, economi'), (0.693, ' child, school, absolut, deport, worker, stori, puerto, latino, everyth, improv')]
# D2007oct30.csv
# [(0.899, ' experi, child, provid, worker, advoc, specif, prevent, begin, author, secur'), (0.859, ' diplomaci, everyth, action, prevent, militari, author, colleagu, begin, provid, potenti'), (0.845, ' secur, respons, privat, specif, import, commit, potenti, advoc, everyth, begin'), (0.889, ' immigr, engag, intend, possibl, diplomaci, action, author, import, specif, militari')]
# R1999oct22.csv
# [(0.822, ' money, import, control, exampl, experi, father, incom, inaud, anyth, number'), (0.74, ' interest, child, teacher, school, level, vital, improv, institut, everyth, liberti'), (0.849, ' school, trade, parent, econom, child, poverti, intern, chines, disciplin, necessari'), (0.723, ' china, propos, bureaucrat, secur, includ, spend, favor, voucher, frank, veteran')]
# G2004sep30.csv
# [(0.487, ' weapon, train, enemi, korea, prolifer, destruct, summit, interest, china, guard'), (0.506, ' saddam, hussein, oppon, threat, afghanistan, intellig, terrorist, disarm, exact, resolut'), (0.484, ' troop, messag, protect, terror, mistak, necessari, chief, decis, achiev, sanction'), (0.413, ' fight, secur, import, laden, korea, allianc, usama, terror, elect, essenti')]
# R2016feb25.csv
# [(0.408, ' compani, watch, insur, money, nobodi, provid, negoti, healthcar, anyth, obamacar'), (0.504, ' israel, audit, stage, border, elect, number, illeg, excus, absolut, libya'), (0.433, ' hispan, religi, releas, import, liberti, korea, return, obamacar, worker, immigr'), (0.357, ' economi, budget, fight, dollar, defend, balanc, respons, child, interest, trade')]
# D2004jan22.csv
# [(0.513, ' money, marriag, import, elect, compani, attack, militari, union, islam, defens'), (0.44, ' respons, reverend, concern, patriot, troop, secur, school, intend, stage, deficit'), (0.476, ' child, protect, insur, fought, lobbyist, account, cathol, level, choos, relationship'), (0.45, ' fight, budget, saddam, balanc, hussein, decis, manufactur, prescript, prison, terror')]
# D2007dec13.csv
# [(0.512, ' energi, corpor, prioriti, secur, interest, money, leadership, depend, break, effort'), (0.553, ' trade, medicar, human, china, school, agreement, labor, standard, restor, import'), (0.423, ' import, child, begin, economi, iowan, subsidi, money, compani, singl, execut'), (0.512, ' teacher, child, relationship, fight, respons, generat, parent, teach, rememb, entir')]
# R1999dec02.csv
# [(0.728, ' secur, interest, retir, karen, benefit, suppos, money, patient, commit, trust'), (0.533, ' child, militari, import, protect, control, anyth, independ, respons, greenspan, worker'), (0.537, ' propos, microsoft, technolog, standard, concern, statement, futur, parent, decis, surplus'), (0.54, ' internet, spend, elect, economi, includ, increas, group, begin, money, provid')]
# D2008feb21.csv
# [(0.583, ' insur, consequ, judgment, worker, command, member, chief, honor, involv, happi'), (0.659, ' cheer, import, voter, trade, standard, elect, afford, dollar, moment, thousand'), (0.571, ' economi, interest, child, provid, number, import, agenda, prepar, negoti, learn'), (0.655, ' border, secur, immigr, respons, leadership, comprehens, reduc, relat, learn, listen')]
# G1960sep26.csv
# [(0.504, ' twenti, dollar, price, effect, satisfi, control, maintain, economi, recommend, market'), (0.593, ' growth, school, field, committe, experi, exampl, judgment, product, platform, result'), (0.585, ' secur, propos, econom, medic, communist, truman, spend, money, strength, resourc'), (0.603, ' teacher, salari, suggest, respons, hundr, sixti, propos, favor, extrem, insur')]
# R2007aug05.csv
# [(0.615, ' money, insur, number, singl, secur, thought, mistak, economi, realiti, speak'), (0.579, ' islam, fight, elect, battl, citizen, probabl, moment, inaud, economi, mistak'), (0.605, ' child, pakistan, truth, option, correct, iraqi, spend, strengthen, musharraf, weapon'), (0.685, ' militari, solut, depend, incom, respons, bridg, crosstalk, complet, entir, recogn')]
# R2007sep05.csv
# [(0.537, ' cheer, number, crime, attack, thought, tortur, marriag, amend, child, intellig'), (0.487, ' pledg, border, mayor, realiti, militari, weapon, terrorist, amnesti, heard, group'), (0.529, ' troop, respons, secur, import, success, attack, terror, pretti, thought, sacrific'), (0.488, ' illeg, immigr, protect, experi, mayor, spend, honor, sanctuari, secur, commit')]
# D2007dec04.csv
# [(0.432, ' immigr, number, secur, exampl, provid, drive, possibl, reach, israel, singl'), (0.423, ' organ, child, weapon, worker, terrorist, revolutionari, guard, declar, diplomaci, resolut'), (0.615, ' china, leverag, chines, economi, human, econom, prevent, engag, interest, competit'), (0.411, ' import, trade, china, enforc, employ, illeg, muslim, worker, listen, leadership')]
# D2000jan17.csv
# [(0.875, ' child, medicaid, father, heart, action, affirm, experi, poverti, discrimin, singl'), (0.916, ' school, immigr, discrimin, futur, profil, teacher, speak, elimin, heart, latino'), (0.909, ' begin, group, commit, human, remov, leader, thought, profil, discrimin, latino'), (0.902, ' latino, perman, voucher, child, elimin, honor, poverti, singl, human, futur')]
# R1999dec13.csv
# [(0.602, ' child, product, spend, import, money, human, citizen, industri, fight, monopoli'), (0.522, ' money, trade, medicar, ethanol, agreement, organ, mention, taiwan, author, independ'), (0.545, ' interest, heart, market, steve, money, secur, control, export, viewer, prescript'), (0.569, ' china, commit, school, intern, israel, worri, bureaucraci, result, parent, protect')]
# R2011sep12.csv
# [(0.596, ' execut, energi, interest, insur, recogn, convers, absolut, thought, afghanistan, parent'), (0.564, ' secur, spend, border, dollar, medicar, compani, incom, immigr, courag, money'), (0.653, ' economi, obamacar, number, privat, budget, repeal, sector, competit, balanc, solut'), (0.647, ' secur, money, import, retir, attack, decis, elect, societi, purpos, cancer')]
# R2008jan06.csv
# [(0.593, ' secur, border, import, incom, human, islam, concern, address, period, spent'), (0.513, ' elect, mistak, ronald, reduc, skill, involv, singl, generat, judgment, absolut'), (0.613, ' spend, amnesti, child, increas, crime, proud, attack, illeg, immigr, pretti'), (0.505, ' experi, leadership, decis, secur, economi, guantanamo, death, truth, energi, result')]
# D2015dec19.csv
# [(0.423, ' economi, number, enforc, region, addict, includ, regim, advoc, crimin, militari'), (0.474, ' coalit, syria, secur, import, destroy, assad, respond, protect, elect, council'), (0.363, ' afford, incom, muslim, propos, privat, success, attack, insur, danger, tuition'), (0.418, ' invest, polic, offer, inform, dictat, weapon, intellig, futur, depart, economi')]
# D2015nov14.csv
# [(0.44, ' money, economi, fight, militari, propos, spend, chanc, child, absolut, attack'), (0.459, ' muslim, defend, revolut, group, number, intern, radic, break, safeti, contribut'), (0.395, ' import, glass, parent, steagal, immigr, threat, proud, everyth, tuition, stage'), (0.408, ' incom, invest, minimum, wealth, conflict, capit, invas, provid, insur, corpor')]
# D2015oct13.csv
# [(0.403, ' immigr, import, elect, billionair, comprehens, heard, insur, compani, soldier, fight'), (0.302, ' child, mayor, marijuana, money, provid, incom, anyon, voter, level, rememb'), (0.37, ' syria, climat, economi, threat, committe, address, econom, leader, learn, school'), (0.43, ' secur, crimin, leadership, afford, protect, inform, wealthi, region, defend, action')]
# R2011sep07.csv
# [(0.575, ' privat, import, sector, school, budget, creation, gallon, balanc, gasolin, situat'), (0.586, ' regul, ronald, spend, broken, effort, provid, obamacar, interest, libya, execut'), (0.586, ' economi, solut, respons, market, energi, money, commit, revenu, incom, child'), (0.649, ' secur, border, number, immigr, illeg, write, benefit, experi, control, parent')]
# R1999dec06.csv
# [(0.698, ' interest, school, worker, hispan, product, number, effort, mother, benefit, money'), (0.722, ' trade, organ, secur, experi, particip, heart, spend, repres, return, encourag'), (0.687, ' money, import, internet, contribut, elect, school, corpor, voter, parent, anyth'), (0.748, ' incom, china, steve, child, price, natur, control, prosper, enjoy, futur')]
# R2011sep05.csv
# [(0.571, ' money, spend, capit, agenc, econom, adopt, growth, respons, child, corpor'), (0.614, ' union, level, suprem, oppos, bureaucrat, economi, entitl, solut, agenc, market'), (0.61, ' reserv, dollar, lincoln, number, jefferson, human, compani, monetari, everyth, abort'), (0.545, ' amend, individu, control, choos, unconstitut, obamacar, balanc, border, budget, simpli')]
# R2011aug11.csv
# [(0.475, ' leadership, child, result, econom, histor, protect, leader, suggest, deficit, terrorist'), (0.57, ' economi, spend, marriag, increas, number, decis, everyth, success, trade, sector'), (0.441, ' money, afghanistan, fight, exact, repres, energi, growth, amend, unemploy, sanction'), (0.45, ' obamacar, secur, border, immigr, budget, repeal, balanc, weapon, abort, dollar')]
# R2008jan10.csv
# [(0.602, ' spend, economi, recess, coalit, control, commit, crime, train, longer, decid'), (0.679, ' money, border, secur, israel, import, decis, musharraf, weapon, anybodi, command'), (0.607, ' illeg, immigr, econom, laden, fight, action, singl, terror, protect, osama'), (0.708, ' ronald, interest, militari, strategi, period, elect, revenu, pakistan, school, confid')]
# R2008jan05.csv
# [(0.542, ' illeg, secur, border, immigr, mayor, natur, fundament, depend, crime, economi'), (0.536, ' crosstalk, attack, islam, employ, radic, import, number, reduc, ronald, troop'), (0.555, ' insur, charli, money, price, militari, dollar, compani, afford, market, hospit'), (0.516, ' amnesti, energi, incent, profit, describ, penalti, sorri, provid, independ, mention')]
# D2016jan17.csv
# [(0.53, ' polic, lester, includ, weapon, attack, crimin, financi, region, secur, everyth'), (0.578, ' insur, andrea, money, frank, industri, rememb, privat, alreadi, comprehens, dollar'), (0.556, ' energi, import, malley, budget, infrastructur, singl, troop, invest, respons, agenda'), (0.529, ' afford, elect, stage, fight, protect, medicar, child, amount, strategi, longer')]
# D2008feb26.csv
# [(0.52, ' afford, provid, absolut, cover, suggest, agreement, accur, experi, trade, brian'), (0.532, ' interest, import, insur, pakistan, compani, afghanistan, independ, iraqi, credit, troop'), (0.501, ' nafta, money, standard, worker, exact, invest, renegoti, labor, qaeda, environment'), (0.517, ' consist, farrakhan, reject, russia, releas, begin, child, sever, pledg, respons')]

# %%
# manually inspect each topic and translate them to a new file
